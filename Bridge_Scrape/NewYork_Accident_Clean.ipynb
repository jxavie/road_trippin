# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv('NewYork_AccidentData.csv')

# %%
df.head()
# Out:
#    Year                   Crash Descriptor   Time      Date Day of Week  \
# 0  2014           Property Damage Accident   8:30  1/3/2014      Friday
# 1  2014  Property Damage & Injury Accident  14:48  1/3/2014      Friday
# 2  2014  Property Damage & Injury Accident  11:30  1/4/2014    Saturday
# 3  2014           Property Damage Accident   7:45  1/3/2014      Friday
# 4  2014           Property Damage Accident  15:11  1/4/2014    Saturday
#
#   Police Report Lighting Conditions Municipality Collision Type Descriptor  \
# 0             Y            Daylight    WATERTOWN                OVERTAKING
# 1             Y            Daylight    WATERTOWN                  REAR END
# 2             Y            Daylight    WATERTOWN                     OTHER
# 3             Y            Daylight    WATERTOWN               RIGHT ANGLE
# 4             Y            Daylight    WATERTOWN               RIGHT ANGLE
#
#   County Name     Road Descriptor Weather Conditions Traffic Control Device  \
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
dropping_df = df.drop(['Time', 'Day of Week', 'Police Report', 'Lighting Conditions',
                     'Traffic Control Device', 'DOT Reference Marker Location',
                     'Pedestrian Bicyclist Action'], axis=1)
dropping_df
# Out:
#         Year                   Crash Descriptor       Date     Municipality  \
# 0       2014           Property Damage Accident 2014-01-03        WATERTOWN
# 1       2014  Property Damage & Injury Accident 2014-01-03        WATERTOWN
# 2       2014  Property Damage & Injury Accident 2014-01-04        WATERTOWN
# 3       2014           Property Damage Accident 2014-01-03        WATERTOWN
# 4       2014           Property Damage Accident 2014-01-04        WATERTOWN
# 5       2014           Property Damage Accident 2014-01-04        FRANKFORT
# 6       2014                    Injury Accident 2014-01-03           WARSAW
# 7       2014           Property Damage Accident 2014-01-03        ROTTERDAM
# 8       2014           Property Damage Accident 2014-01-03      EAST AURORA
# 9       2014  Property Damage & Injury Accident 2014-01-03           AURORA
# 10      2014  Property Damage & Injury Accident 2014-01-03          AMHERST
# ...

# %%
dropping_df["Event Descriptor"].value_counts()
# Out:
# Other Motor Vehicle, Collision With                             609589
# Deer                                                             68012
# Pedestrian, Collision With                                       41109
# Guide Rail - Not At End, Collision With Fixed Object             24171
# Earth Embankment/Rock Cut/Ditch, Collision With Fixed Object     20633
# Light Support/Utility Pole, Collision With Fixed Object          18120
# Bicyclist, Collision With                                        17289
# Tree, Collision With Fixed Object                                17224
# Other Fixed Object*, Collision With Fixed Object                  9429
# Animal, Collision With                                            8510
# Other Object (Not Fixed)*, Collision With                         8045
# Sign Post, Collision With Fixed Object                            7727
# Building/Wall, Collision With Fixed Object                        5286
# ...

# %%
ditch_df = dropping_df.loc[dropping_df["Event Descriptor"] == "Earth Embankment/Rock Cut/Ditch, Collision With Fixed Object", :]
ditch_df
# Out:
#         Year                   Crash Descriptor       Date     Municipality  \
# 22      2014  Property Damage & Injury Accident 2014-01-02       MT. MORRIS
# 24      2014           Property Damage Accident 2014-01-04             YORK
# 31      2015           Property Damage Accident 2015-01-03          FLORIDA
# 32      2015           Property Damage Accident 2015-01-04        AMSTERDAM
# 79      2015  Property Damage & Injury Accident 2015-01-03         CLARKSON
# 91      2015           Property Damage Accident 2015-01-03          LANSING
# 92      2015           Property Damage Accident 2015-01-03           GROTON
# 102     2015           Property Damage Accident 2015-01-04           FULTON
# 103     2015           Property Damage Accident 2015-01-04       MIDDLEBURG
# 106     2015           Property Damage Accident 2015-01-03           ELLERY
# 107     2015  Property Damage & Injury Accident 2015-01-03     FRENCH CREEK
# ...
