# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('DC_Potholes.csv')
df.head(10)
# Out:
#            X          Y  OBJECTID SERVICECODE SERVICECODEDESCRIPTION  \
# 0 -77.064129  38.923299       295       S0301                Pothole
# 1 -77.061381  38.920003       296       S0301                Pothole
# 2 -77.098114  38.919528       297       S0301                Pothole
# 3 -77.028377  38.924760       298       S0301                Pothole
# 4 -76.995330  38.879792       299       S0301                Pothole
# 5 -77.031590  38.902927       300       S0301                Pothole
# 6 -77.001317  38.821292       301       S0301                Pothole
# 7 -77.001317  38.821292       302       S0301                Pothole
# 8 -76.982478  38.851619       303       S0301                Pothole
# 9 -77.034811  38.911288       304       S0301                Pothole
#
#         SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0  Toa-Street & Bridge Maintenance                DDOT
# 1  Toa-Street & Bridge Maintenance                DDOT
# ...

# %%
df["ADDDATE"] = pd.to_datetime(df["ADDDATE"])

# %%
df.head()
# Out:
#            X          Y  OBJECTID SERVICECODE SERVICECODEDESCRIPTION  \
# 0 -77.064129  38.923299       295       S0301                Pothole
# 1 -77.061381  38.920003       296       S0301                Pothole
# 2 -77.098114  38.919528       297       S0301                Pothole
# 3 -77.028377  38.924760       298       S0301                Pothole
# 4 -76.995330  38.879792       299       S0301                Pothole
#
#         SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0  Toa-Street & Bridge Maintenance                DDOT
# 1  Toa-Street & Bridge Maintenance                DDOT
# 2  Toa-Street & Bridge Maintenance                DDOT
# 3  Toa-Street & Bridge Maintenance                DDOT
# 4  Toa-Street & Bridge Maintenance                DDOT
#
#                     ADDDATE            RESOLUTIONDATE  \
# 0 2020-01-18 18:27:46+00:00  2020-01-21T16:05:34.000Z
# 1 2020-01-18 18:28:27+00:00  2020-01-21T16:05:18.000Z
# ...

# %%
df.to_csv('Cleaned_Pothole')
