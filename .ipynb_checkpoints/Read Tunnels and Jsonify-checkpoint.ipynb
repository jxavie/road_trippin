# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Config variables
from config import dbuser, dbpwd, dbhost, dbport, dbname

# Import Pandas
import pandas as pd
import pprint as pp

import json

# %%
# Cloud MySQL Database Connection on AWS
engine = create_engine(f"mysql://{dbuser}:{dbpwd}@{dbhost}:{dbport}/{dbname}")

# %%
# Create a remote database engine connection
conn = engine.connect()

# %%
tunnels = pd.read_sql_query('select * from tunnels', con=engine)
tunnels.head()
# Out:
#    Unnamed: 0    Tunnel_Number  \
# 0           0          53C1210
# 1           1             1113
# 2           2  IN2MARION000001
# 3           3  IN2MARION000002
# 4           4  IN2MARION000003
#
#                                          Tunnel_Name            State_Code  \
# 0                                 Hope Street Tunnel            California
# 1                 12th St SW Tunnel at Southwest Fwy  District of Columbia
# 2  South Capitol Avenue under CSX RR and Other Items               Indiana
# 3       Illinois Street under CSX RR and Other Items               Indiana
# 4       Meridian Street under CSX RR and Other Items               Indiana
#
#     Route_Type   Latitude   Longitude  Year_Built  Year_Rehabilitated  Lanes  \
# 0  City Street  34.048339 -118.257256        1972                   0      4
# 1  City Street  38.882778  -77.028056        1959                   0      4
# 2  City Street  39.762910   86.161866        1888                1984      4
# 3  City Street  39.762042   86.160099        1888                1984      4
# 4  City Street  39.762023   86.158331        1888                1984      4
#
#    ...  Toll  NHS  STRAHNET           Class  Length  Under_Nav_Water  \
# 0  ...     0    0         1  Minor Arterial      75                0
# 1  ...     0    1         0  Minor Arterial     295                0
# 2  ...     0    0         0  Minor Arterial     353                0
# 3  ...     0    0         0  Minor Arterial     310                0
# 4  ...     0    0         0  Minor Arterial     276                0
#
#   Number_Bores  Tunnel_Shape  Ground_Conditions  Condition
# 0            1          Oval               Soil          2
# 1            1          Oval               Soil          2
# 2            1          Oval               Soil         13
# 3            1          Oval               Soil          4
# 4            1          Oval               Soil         15
#
# [5 rows x 23 columns]

# %%
# json_data = roads.to_json(orient ='index')
tunnels_json = tunnels.to_dict('records')
print(json.dumps(tunnels_json, indent=4))
# Out:
# [
#     {
#         "Unnamed: 0": 0,
#         "Tunnel_Number": "53C1210",
#         "Tunnel_Name": "Hope Street Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 34.04833889,
#         "Longitude": -118.2572556,
#         "Year_Built": 1972,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 9000,
#         "AADTT": 90.0,
#         "Detour Length": 0,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 1,
#         "Class": "Minor Arterial",
#         "Length": 75,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 1,
#         "Tunnel_Number": "1113",
#         "Tunnel_Name": "12th St SW Tunnel at Southwest Fwy",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.88277778,
#         "Longitude": -77.02805556,
#         "Year_Built": 1959,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 10500,
#         "AADTT": 210.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 295,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 2,
#         "Tunnel_Number": "IN2MARION000001",
#         "Tunnel_Name": "South Capitol Avenue under CSX RR and Other Items",
#         "State_Code": "Indiana",
#         "Route_Type": "City Street",
#         "Latitude": 39.76291,
#         "Longitude": 86.161866,
#         "Year_Built": 1888,
#         "Year_Rehabilitated": 1984,
#         "Lanes": 4,
#         "AADT": 11322,
#         "AADTT": 566.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 353,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 13
#     },
#     {
#         "Unnamed: 0": 3,
#         "Tunnel_Number": "IN2MARION000002",
#         "Tunnel_Name": "Illinois Street under CSX RR and Other Items",
#         "State_Code": "Indiana",
#         "Route_Type": "City Street",
#         "Latitude": 39.762042,
#         "Longitude": 86.160099,
#         "Year_Built": 1888,
#         "Year_Rehabilitated": 1984,
#         "Lanes": 4,
#         "AADT": 16130,
#         "AADTT": 806.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 310,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 4
#     },
#     {
#         "Unnamed: 0": 4,
#         "Tunnel_Number": "IN2MARION000003",
#         "Tunnel_Name": "Meridian Street under CSX RR and Other Items",
#         "State_Code": "Indiana",
#         "Route_Type": "City Street",
#         "Latitude": 39.762023,
#         "Longitude": 86.158331,
#         "Year_Built": 1888,
#         "Year_Rehabilitated": 1984,
#         "Lanes": 4,
#         "AADT": 9442,
#         "AADTT": 472.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 276,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 15
#     },
#     {
#         "Unnamed: 0": 5,
#         "Tunnel_Number": "IN2MARION000005",
#         "Tunnel_Name": "East Street under CSX RR and Heliport",
#         "State_Code": "Indiana",
#         "Route_Type": "City Street",
#         "Latitude": 39.76604,
#         "Longitude": 86.149065,
#         "Year_Built": 1888,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 7155,
#         "AADTT": 357.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 375,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 12
#     },
#     {
#         "Unnamed: 0": 6,
#         "Tunnel_Number": "50008",
#         "Tunnel_Name": "HOLLAND AIRPORT",
#         "State_Code": "Michigan",
#         "Route_Type": "City Street",
#         "Latitude": 42.7416,
#         "Longitude": -86.1174,
#         "Year_Built": 2003,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 22030,
#         "AADTT": 334.0,
#         "Detour Length": 5,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 986,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 5
#     },
#     {
#         "Unnamed: 0": 7,
#         "Tunnel_Number": "33TU0355601",
#         "Tunnel_Name": "Wilcox Tunnel",
#         "State_Code": "Tennessee",
#         "Route_Type": "City Street",
#         "Latitude": 36.051733,
#         "Longitude": -84.25375,
#         "Year_Built": 1930,
#         "Year_Rehabilitated": 2015,
#         "Lanes": 2,
#         "AADT": 14360,
#         "AADTT": 287.0,
#         "Detour Length": 999,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 21,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 8,
#         "Tunnel_Number": "180570P00225001",
#         "Tunnel_Name": "Addison Airport Toll Tunnel",
#         "State_Code": "Texas",
#         "Route_Type": "City Street",
#         "Latitude": 32.969029,
#         "Longitude": -96.838721,
#         "Year_Built": 1999,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 6275,
#         "AADTT": 55.0,
#         "Detour Length": 3,
#         "Toll": 1,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 1650,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 9,
#         "Tunnel_Number": "33TUSR00803",
#         "Tunnel_Name": "Stringers Ridge Tunnel",
#         "State_Code": "Tennessee",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 35.07321111,
#         "Longitude": 85.31884167,
#         "Year_Built": 1910,
#         "Year_Rehabilitated": 1958,
#         "Lanes": 2,
#         "AADT": 13910,
#         "AADTT": 2504.0,
#         "Detour Length": 4,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 300,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 5
#     },
#     {
#         "Unnamed: 0": 10,
#         "Tunnel_Number": "3500C10",
#         "Tunnel_Name": "Atlantic City Expressway Connector Tunnel",
#         "State_Code": "New Jersey",
#         "Route_Type": "State Highway",
#         "Latitude": 39.370147,
#         "Longitude": -74.445127,
#         "Year_Built": 2001,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 24590,
#         "AADTT": 984.0,
#         "Detour Length": 2,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Arterial",
#         "Length": 1906,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 10
#     },
#     {
#         "Unnamed: 0": 11,
#         "Tunnel_Number": "53C0202",
#         "Tunnel_Name": "Spring Street Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 33.81166667,
#         "Longitude": -118.1438889,
#         "Year_Built": 1978,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 26288,
#         "AADTT": 525.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 1096,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 8
#     },
#     {
#         "Unnamed: 0": 12,
#         "Tunnel_Number": "54 0915",
#         "Tunnel_Name": "Mathews Ranch Rd Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 34.245998,
#         "Longitude": -117.435989,
#         "Year_Built": 1969,
#         "Year_Rehabilitated": 0,
#         "Lanes": 1,
#         "AADT": 122000,
#         "AADTT": 18300.0,
#         "Detour Length": 5,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 1,
#         "Class": "Local",
#         "Length": 282,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 0
#     },
#     {
#         "Unnamed: 0": 13,
#         "Tunnel_Number": "55 0840L",
#         "Tunnel_Name": "Disney Way West Bound Tunnel 1",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 33.805557,
#         "Longitude": -117.906387,
#         "Year_Built": 2000,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 5000,
#         "AADTT": 100.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 265,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 0
#     },
#     {
#         "Unnamed: 0": 14,
#         "Tunnel_Number": "55 0840R",
#         "Tunnel_Name": "Disney Way West Bound Tunnel 2",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 33.805594,
#         "Longitude": -117.904768,
#         "Year_Built": 2000,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 5000,
#         "AADTT": 100.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 213,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 15,
#         "Tunnel_Number": "55C0497",
#         "Tunnel_Name": "Salt Creek Service Road Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 33.50581667,
#         "Longitude": -117.7078389,
#         "Year_Built": 1979,
#         "Year_Rehabilitated": 0,
#         "Lanes": 1,
#         "AADT": 17900,
#         "AADTT": 537.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 177,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 16,
#         "Tunnel_Number": "D-01-CC-185",
#         "Tunnel_Name": "Speer Blvd",
#         "State_Code": "Colorado",
#         "Route_Type": "City Street",
#         "Latitude": 39.72685,
#         "Longitude": -104.98781111,
#         "Year_Built": 1995,
#         "Year_Rehabilitated": 0,
#         "Lanes": 3,
#         "AADT": 24609,
#         "AADTT": 1230.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 710,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 17,
#         "Tunnel_Number": "50007",
#         "Tunnel_Name": "COBO HALL",
#         "State_Code": "Michigan",
#         "Route_Type": "City Street",
#         "Latitude": 42.3279,
#         "Longitude": -83.0489,
#         "Year_Built": 1960,
#         "Year_Rehabilitated": 1987,
#         "Lanes": 3,
#         "AADT": 9833,
#         "AADTT": 246.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 816,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 12
#     },
#     {
#         "Unnamed: 0": 18,
#         "Tunnel_Number": "28 0257",
#         "Tunnel_Name": "Bay Point L&R Tunnels",
#         "State_Code": "California",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 38.01205278,
#         "Longitude": -122.0056056,
#         "Year_Built": 1976,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 14600,
#         "AADTT": 1022.0,
#         "Detour Length": 0,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 1,
#         "Class": "Local",
#         "Length": 649,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 19,
#         "Tunnel_Number": "B16T40SLTMBT000",
#         "Tunnel_Name": "SILVER LINE TUNNEL",
#         "State_Code": "Massachusetts",
#         "Route_Type": "Other",
#         "Latitude": 42.34767222,
#         "Longitude": -71.04085833,
#         "Year_Built": 2004,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 261,
#         "AADTT": 260.0,
#         "Detour Length": 999,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 6233,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 7
#     },
#     {
#         "Unnamed: 0": 20,
#         "Tunnel_Number": "C01T41HSTMBT000",
#         "Tunnel_Name": "HARVARD SQUARE TUNNEL",
#         "State_Code": "Massachusetts",
#         "Route_Type": "Other",
#         "Latitude": 42.376,
#         "Longitude": -71.1192,
#         "Year_Built": 1927,
#         "Year_Rehabilitated": 1948,
#         "Lanes": 2,
#         "AADT": 1421,
#         "AADTT": 1420.0,
#         "Detour Length": 999,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 2904,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 9
#     },
#     {
#         "Unnamed: 0": 21,
#         "Tunnel_Number": "50002",
#         "Tunnel_Name": "TAXIWAY F",
#         "State_Code": "Michigan",
#         "Route_Type": "Other",
#         "Latitude": 42.2317,
#         "Longitude": -83.3498,
#         "Year_Built": 1997,
#         "Year_Rehabilitated": 0,
#         "Lanes": 9,
#         "AADT": 27100,
#         "AADTT": 200.0,
#         "Detour Length": 9,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 268,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 0
#     },
#     {
#         "Unnamed: 0": 22,
#         "Tunnel_Number": "50003",
#         "Tunnel_Name": "RUNWAY 9, TAXIWAY J AND T",
#         "State_Code": "Michigan",
#         "Route_Type": "Other",
#         "Latitude": 42.2002,
#         "Longitude": -83.5396,
#         "Year_Built": 1991,
#         "Year_Rehabilitated": 0,
#         "Lanes": 7,
#         "AADT": 27100,
#         "AADTT": 200.0,
#         "Detour Length": 9,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 1528,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 8
#     },
#     {
#         "Unnamed: 0": 23,
#         "Tunnel_Number": "50004",
#         "Tunnel_Name": "RUNWAY 9, TAXIWAY V",
#         "State_Code": "Michigan",
#         "Route_Type": "Other",
#         "Latitude": 42.2178,
#         "Longitude": -83.3468,
#         "Year_Built": 1997,
#         "Year_Rehabilitated": 0,
#         "Lanes": 8,
#         "AADT": 27100,
#         "AADTT": 200.0,
#         "Detour Length": 9,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Local",
#         "Length": 895,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 24,
#         "Tunnel_Number": "44C0064",
#         "Tunnel_Name": "Custom House Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 36.602184,
#         "Longitude": -121.893219,
#         "Year_Built": 1968,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 1420,
#         "AADTT": 284.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1000,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 25,
#         "Tunnel_Number": "53C0477",
#         "Tunnel_Name": "Sherman Way Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 34.201187,
#         "Longitude": -118.490707,
#         "Year_Built": 1958,
#         "Year_Rehabilitated": 0,
#         "Lanes": 6,
#         "AADT": 45065,
#         "AADTT": 901.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 728,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 26,
#         "Tunnel_Number": "53C1771",
#         "Tunnel_Name": "City Hall E Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 34.05222778,
#         "Longitude": -118.2416583,
#         "Year_Built": 1971,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 17000,
#         "AADTT": 340.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 48,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 0
#     },
#     {
#         "Unnamed: 0": 27,
#         "Tunnel_Number": "100",
#         "Tunnel_Name": "Scott Circle Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.45416667,
#         "Longitude": -77.03654167,
#         "Year_Built": 1941,
#         "Year_Rehabilitated": 2005,
#         "Lanes": 4,
#         "AADT": 12700,
#         "AADTT": 380.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 221,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 3
#     },
#     {
#         "Unnamed: 0": 28,
#         "Tunnel_Number": "101",
#         "Tunnel_Name": "DuPont Circle Roadway Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.90102778,
#         "Longitude": -77.04388889,
#         "Year_Built": 1950,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 24500,
#         "AADTT": 735.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 579,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 29,
#         "Tunnel_Number": "102",
#         "Tunnel_Name": "Washington Circle Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.90222222,
#         "Longitude": -77.04833333,
#         "Year_Built": 1960,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 41500,
#         "AADTT": 415.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 519,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 30,
#         "Tunnel_Number": "99",
#         "Tunnel_Name": "Thomas Circle Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.90583333,
#         "Longitude": -77.0325,
#         "Year_Built": 1940,
#         "Year_Rehabilitated": 2005,
#         "Lanes": 4,
#         "AADT": 53000,
#         "AADTT": 1060.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 415,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 31,
#         "Tunnel_Number": "IN2MARION000004",
#         "Tunnel_Name": "Pennsylvania Street under CSX RR and Other Items",
#         "State_Code": "Indiana",
#         "Route_Type": "City Street",
#         "Latitude": 39.763083,
#         "Longitude": 86.15644,
#         "Year_Built": 1888,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 10927,
#         "AADTT": 546.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 290,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 15
#     },
#     {
#         "Unnamed: 0": 32,
#         "Tunnel_Number": "121020AA9960001",
#         "Tunnel_Name": "Washburn Tunnel",
#         "State_Code": "Texas",
#         "Route_Type": "City Street",
#         "Latitude": 29.72232057,
#         "Longitude": -95.2117132,
#         "Year_Built": 1950,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 20000,
#         "AADTT": 0.0,
#         "Detour Length": 3,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 2936,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 10
#     },
#     {
#         "Unnamed: 0": 33,
#         "Tunnel_Number": "860003",
#         "Tunnel_Name": "Henry E. Kinney Tunnel",
#         "State_Code": "Florida",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 26.11694444,
#         "Longitude": -80.13722222,
#         "Year_Built": 1960,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 44500,
#         "AADTT": 1335.0,
#         "Detour Length": 3,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 864,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 7
#     },
#     {
#         "Unnamed: 0": 34,
#         "Tunnel_Number": "100000",
#         "Tunnel_Name": "LINDBERGH BOUELVARD US 67 RUNWAY TUNNEL",
#         "State_Code": "Missouri",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 38.75588806,
#         "Longitude": -90.3958075,
#         "Year_Built": 2006,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 20327,
#         "AADTT": 1016.0,
#         "Detour Length": 4,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1420,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 7
#     },
#     {
#         "Unnamed: 0": 35,
#         "Tunnel_Number": "19TUSR00101",
#         "Tunnel_Name": "NASHVILLE INTERNATIONALAIRPORT RUNWAY TUNNEL",
#         "State_Code": "Tennessee",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 36.11143,
#         "Longitude": 86.68577,
#         "Year_Built": 1996,
#         "Year_Rehabilitated": 1997,
#         "Lanes": 6,
#         "AADT": 30550,
#         "AADTT": 3666.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1016,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 7
#     },
#     {
#         "Unnamed: 0": 36,
#         "Tunnel_Number": "33TUSR00801",
#         "Tunnel_Name": "BACHMAN TUNNEL (LEFT BORE)",
#         "State_Code": "Tennessee",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 35.00936944,
#         "Longitude": 85.27107222,
#         "Year_Built": 1929,
#         "Year_Rehabilitated": 1969,
#         "Lanes": 1,
#         "AADT": 17610,
#         "AADTT": 352.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1034,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 4
#     },
#     {
#         "Unnamed: 0": 37,
#         "Tunnel_Number": "33TUSR00802",
#         "Tunnel_Name": "BACHMAN TUNNEL (RIGHT BORE)",
#         "State_Code": "Tennessee",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 35.00924722,
#         "Longitude": 85.27108056,
#         "Year_Built": 1929,
#         "Year_Rehabilitated": 1969,
#         "Lanes": 1,
#         "AADT": 17610,
#         "AADTT": 352.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1034,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 4
#     },
#     {
#         "Unnamed: 0": 38,
#         "Tunnel_Number": "53 0008",
#         "Tunnel_Name": "McClure Tunnel",
#         "State_Code": "California",
#         "Route_Type": "Interstate Highway",
#         "Latitude": 34.01147778,
#         "Longitude": -118.4945528,
#         "Year_Built": 1935,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 59000,
#         "AADTT": 1770.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 400,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 39,
#         "Tunnel_Number": "17 0016",
#         "Tunnel_Name": "Donner Creek Tunnel",
#         "State_Code": "California",
#         "Route_Type": "State Highway",
#         "Latitude": 39.317775,
#         "Longitude": -120.2057833,
#         "Year_Built": 1929,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 18400,
#         "AADTT": 920.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 75,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 40,
#         "Tunnel_Number": "33 0106L",
#         "Tunnel_Name": "Webster Street Tube (SR 260 SB)",
#         "State_Code": "California",
#         "Route_Type": "State Highway",
#         "Latitude": 37.78807774,
#         "Longitude": -122.27816973,
#         "Year_Built": 1963,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 55000,
#         "AADTT": 1650.0,
#         "Detour Length": 6,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 3350,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 14
#     },
#     {
#         "Unnamed: 0": 41,
#         "Tunnel_Number": "33 0106R",
#         "Tunnel_Name": "Posey Tube (SR 260 NB)",
#         "State_Code": "California",
#         "Route_Type": "State Highway",
#         "Latitude": 37.78744035,
#         "Longitude": -122.27657404,
#         "Year_Built": 1927,
#         "Year_Rehabilitated": 1964,
#         "Lanes": 2,
#         "AADT": 47500,
#         "AADTT": 950.0,
#         "Detour Length": 6,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 1,
#         "Class": "Principal Arterial - Other",
#         "Length": 3545,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 12
#     },
#     {
#         "Unnamed: 0": 42,
#         "Tunnel_Number": "53C2270",
#         "Tunnel_Name": "Lakewood Blvd (St.Rte. 19) Tunnel",
#         "State_Code": "California",
#         "Route_Type": "State Highway",
#         "Latitude": 33.807982,
#         "Longitude": -118.141512,
#         "Year_Built": 1958,
#         "Year_Rehabilitated": 1982,
#         "Lanes": 6,
#         "AADT": 39055,
#         "AADTT": 781.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1005,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 43,
#         "Tunnel_Number": "S17T44SOMDOT000",
#         "Tunnel_Name": "SOMERVILLE TUNNEL",
#         "State_Code": "Massachusetts",
#         "Route_Type": "State Highway",
#         "Latitude": 42.392743,
#         "Longitude": -71.085788,
#         "Year_Built": 1970,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 58800,
#         "AADTT": 2352.0,
#         "Detour Length": 0,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 452,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 44,
#         "Tunnel_Number": "50006",
#         "Tunnel_Name": "COBO HALL",
#         "State_Code": "Michigan",
#         "Route_Type": "State Highway",
#         "Latitude": 42.3265,
#         "Longitude": -83.0491,
#         "Year_Built": 1960,
#         "Year_Rehabilitated": 0,
#         "Lanes": 6,
#         "AADT": 29660,
#         "AADTT": 2226.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1045,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 7
#     },
#     {
#         "Unnamed: 0": 45,
#         "Tunnel_Number": "27191",
#         "Tunnel_Name": "MINNEHAHA TUNNEL",
#         "State_Code": "Minnesota",
#         "Route_Type": "State Highway",
#         "Latitude": 44.91607222,
#         "Longitude": 93.21474444,
#         "Year_Built": 1999,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 23446,
#         "AADTT": 1172.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 644,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 5
#     },
#     {
#         "Unnamed: 0": 46,
#         "Tunnel_Number": "33TUSR00201",
#         "Tunnel_Name": "McCALLIE TUNNEL (LEFT BORE)",
#         "State_Code": "Tennessee",
#         "Route_Type": "State Highway",
#         "Latitude": 35.029808,
#         "Longitude": 85.258568,
#         "Year_Built": 1930,
#         "Year_Rehabilitated": 1990,
#         "Lanes": 2,
#         "AADT": 32970,
#         "AADTT": 4286.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1010,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 47,
#         "Tunnel_Number": "33TUSR00202",
#         "Tunnel_Name": "McCALLIE TUNNEL (RIGHT BORE)",
#         "State_Code": "Tennessee",
#         "Route_Type": "State Highway",
#         "Latitude": 35.029808,
#         "Longitude": 85.258568,
#         "Year_Built": 1930,
#         "Year_Rehabilitated": 1990,
#         "Lanes": 2,
#         "AADT": 32970,
#         "AADTT": 4286.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 946,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 48,
#         "Tunnel_Number": "T1978N",
#         "Tunnel_Name": "Airport runway",
#         "State_Code": "Nevada",
#         "Route_Type": "County Highway",
#         "Latitude": 36.07221944,
#         "Longitude": 115.14572222,
#         "Year_Built": 1994,
#         "Year_Rehabilitated": 0,
#         "Lanes": 3,
#         "AADT": 47375,
#         "AADTT": 3790.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 1,
#         "Class": "Principal Arterial - Other",
#         "Length": 2729,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 7
#     },
#     {
#         "Unnamed: 0": 49,
#         "Tunnel_Number": "T1978S",
#         "Tunnel_Name": "Airport runway",
#         "State_Code": "Nevada",
#         "Route_Type": "County Highway",
#         "Latitude": 36.07226944,
#         "Longitude": 115.14604167,
#         "Year_Built": 1994,
#         "Year_Rehabilitated": 0,
#         "Lanes": 3,
#         "AADT": 47375,
#         "AADTT": 3790.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 1,
#         "Class": "Principal Arterial - Other",
#         "Length": 2729,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 6
#     },
#     {
#         "Unnamed: 0": 50,
#         "Tunnel_Number": "79TU0281301",
#         "Tunnel_Name": "Memphis Airport Runway Tunnel",
#         "State_Code": "Tennessee",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.0522444,
#         "Longitude": 89.9780194,
#         "Year_Built": 1980,
#         "Year_Rehabilitated": 1997,
#         "Lanes": 7,
#         "AADT": 29000,
#         "AADTT": 2320.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Other",
#         "Length": 1089,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 8
#     },
#     {
#         "Unnamed: 0": 51,
#         "Tunnel_Number": "37 0654K",
#         "Tunnel_Name": "Airport Blvd I-880S On-Ramp Tunnel",
#         "State_Code": "California",
#         "Route_Type": "City Street",
#         "Latitude": 37.350254,
#         "Longitude": -121.916866,
#         "Year_Built": 2005,
#         "Year_Rehabilitated": 0,
#         "Lanes": 1,
#         "AADT": 12000,
#         "AADTT": 720.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Major Collector",
#         "Length": 546,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 52,
#         "Tunnel_Number": "1209",
#         "Tunnel_Name": "E St NW Expressway Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.86911111,
#         "Longitude": -77.04694444,
#         "Year_Built": 1964,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 14000,
#         "AADTT": 280.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 635,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 53,
#         "Tunnel_Number": "1302",
#         "Tunnel_Name": "Potomac Parkway Tunnel at Virginia Ave NW",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.76265278,
#         "Longitude": -77.04785278,
#         "Year_Built": 1962,
#         "Year_Rehabilitated": 0,
#         "Lanes": 8,
#         "AADT": 22500,
#         "AADTT": 450.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 558,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 54,
#         "Tunnel_Number": "1409",
#         "Tunnel_Name": "Barney Circle Ramp Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.87829722,
#         "Longitude": -76.98178056,
#         "Year_Built": 1974,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 12500,
#         "AADTT": 350.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 304,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 0
#     },
#     {
#         "Unnamed: 0": 55,
#         "Tunnel_Number": "1410",
#         "Tunnel_Name": "Barney Circle Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.87793056,
#         "Longitude": -76.98126667,
#         "Year_Built": 1974,
#         "Year_Rehabilitated": 0,
#         "Lanes": 4,
#         "AADT": 500,
#         "AADTT": 50.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 440,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 56,
#         "Tunnel_Number": "172N",
#         "Tunnel_Name": "12th St North Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.88972222,
#         "Longitude": -77.02805556,
#         "Year_Built": 1964,
#         "Year_Rehabilitated": 1999,
#         "Lanes": 3,
#         "AADT": 39400,
#         "AADTT": 788.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 730,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 4
#     },
#     {
#         "Unnamed: 0": 57,
#         "Tunnel_Number": "172S",
#         "Tunnel_Name": "12th St South Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.88805556,
#         "Longitude": -77.02805556,
#         "Year_Built": 1964,
#         "Year_Rehabilitated": 1999,
#         "Lanes": 2,
#         "AADT": 39400,
#         "AADTT": 788.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 260,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 5
#     },
#     {
#         "Unnamed: 0": 58,
#         "Tunnel_Number": "173",
#         "Tunnel_Name": "9th St Tunnel",
#         "State_Code": "District of Columbia",
#         "Route_Type": "City Street",
#         "Latitude": 38.88833333,
#         "Longitude": -77.025,
#         "Year_Built": 1970,
#         "Year_Rehabilitated": 2000,
#         "Lanes": 3,
#         "AADT": 27300,
#         "AADTT": 546.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 1610,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 0
#     },
#     {
#         "Unnamed: 0": 59,
#         "Tunnel_Number": "B16T33CANDOTV15",
#         "Tunnel_Name": "CANA TUNNEL NORTHBOUND",
#         "State_Code": "Massachusetts",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 42.3711,
#         "Longitude": -71.0628,
#         "Year_Built": 1988,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 83734,
#         "AADTT": 3429.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 1506,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 13
#     },
#     {
#         "Unnamed: 0": 60,
#         "Tunnel_Number": "B16T34CASDOTV14",
#         "Tunnel_Name": "CANA TUNNEL SOUTHBOUND",
#         "State_Code": "Massachusetts",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 42.3725,
#         "Longitude": -71.0604,
#         "Year_Built": 1988,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 83734,
#         "AADTT": 3429.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 824,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 12
#     },
#     {
#         "Unnamed: 0": 61,
#         "Tunnel_Number": "CBBT00000000002",
#         "Tunnel_Name": "Chesapeake Channel Tunnel",
#         "State_Code": "Virginia",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 37.0364,
#         "Longitude": -76.0768,
#         "Year_Built": 1964,
#         "Year_Rehabilitated": 2014,
#         "Lanes": 2,
#         "AADT": 10039,
#         "AADTT": 965.0,
#         "Detour Length": 425,
#         "Toll": 2,
#         "NHS": 0,
#         "STRAHNET": 1,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 5424,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 3
#     },
#     {
#         "Unnamed: 0": 62,
#         "Tunnel_Number": "CBBT0000000001R",
#         "Tunnel_Name": "Thimble Shoal Tunnel",
#         "State_Code": "Virginia",
#         "Route_Type": "U.S. Numbered Highway",
#         "Latitude": 36.9662,
#         "Longitude": -76.1126,
#         "Year_Built": 1964,
#         "Year_Rehabilitated": 2014,
#         "Lanes": 2,
#         "AADT": 10039,
#         "AADTT": 965.0,
#         "Detour Length": 425,
#         "Toll": 2,
#         "NHS": 0,
#         "STRAHNET": 1,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 5738,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 8
#     },
#     {
#         "Unnamed: 0": 63,
#         "Tunnel_Number": "VDOT0000000008R",
#         "Tunnel_Name": "Downtown Tunnel EBL",
#         "State_Code": "Virginia",
#         "Route_Type": "Interstate Highway",
#         "Latitude": 36.83093889,
#         "Longitude": -76.3008417,
#         "Year_Built": 1987,
#         "Year_Rehabilitated": 2015,
#         "Lanes": 2,
#         "AADT": 40000,
#         "AADTT": 1600.0,
#         "Detour Length": 7,
#         "Toll": 1,
#         "NHS": 1,
#         "STRAHNET": 1,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 3814,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 10
#     },
#     {
#         "Unnamed: 0": 64,
#         "Tunnel_Number": "VDOT0000000009L",
#         "Tunnel_Name": "Downtown Tunnel WBL",
#         "State_Code": "Virginia",
#         "Route_Type": "Interstate Highway",
#         "Latitude": 36.834798,
#         "Longitude": -76.288895,
#         "Year_Built": 1952,
#         "Year_Rehabilitated": 2015,
#         "Lanes": 2,
#         "AADT": 36000,
#         "AADTT": 1440.0,
#         "Detour Length": 7,
#         "Toll": 1,
#         "NHS": 1,
#         "STRAHNET": 1,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 3350,
#         "Under_Nav_Water": 1,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 9
#     },
#     {
#         "Unnamed: 0": 65,
#         "Tunnel_Number": "35 0173L",
#         "Tunnel_Name": "S280/S1 SEP Tunnel",
#         "State_Code": "California",
#         "Route_Type": "State Highway",
#         "Latitude": 37.70547222,
#         "Longitude": -122.4715,
#         "Year_Built": 1965,
#         "Year_Rehabilitated": 0,
#         "Lanes": 6,
#         "AADT": 49500,
#         "AADTT": 495.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 719,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 66,
#         "Tunnel_Number": "53 0845",
#         "Tunnel_Name": "International Airport Tunnel",
#         "State_Code": "California",
#         "Route_Type": "State Highway",
#         "Latitude": 33.93459167,
#         "Longitude": -118.39605833,
#         "Year_Built": 1952,
#         "Year_Rehabilitated": 2001,
#         "Lanes": 6,
#         "AADT": 60800,
#         "AADTT": 1824.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 1910,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 2,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 8
#     },
#     {
#         "Unnamed: 0": 67,
#         "Tunnel_Number": "55 0780G",
#         "Tunnel_Name": "N241-S133 Connector Tunnel",
#         "State_Code": "California",
#         "Route_Type": "State Highway",
#         "Latitude": 33.710265,
#         "Longitude": -117.724397,
#         "Year_Built": 1998,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 18940,
#         "AADTT": 4.0,
#         "Detour Length": 5,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Principal Arterial - Freeways and Expressways",
#         "Length": 405,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Oval",
#         "Ground_Conditions": "Soil",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 68,
#         "Tunnel_Number": "55 0784G",
#         "Tunnel_Name": "N133-N241 Connector Tunnel",
# ...
#         "Latitude": 35.42216491,
#         "Longitude": -82.74189,
#         "Year_Built": 1964,
#         "Year_Rehabilitated": 1985,
#         "Lanes": 2,
#         "AADT": 5007,
#         "AADTT": 50.0,
#         "Detour Length": 50,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 583,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 361,
#         "Tunnel_Number": "5140150P0000000",
#         "Tunnel_Name": "BUCK SPRING TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.41808319,
#         "Longitude": -82.74692,
#         "Year_Built": 1964,
#         "Year_Rehabilitated": 1985,
#         "Lanes": 2,
#         "AADT": 5007,
#         "AADTT": 50.0,
#         "Detour Length": 50,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 468,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 362,
#         "Tunnel_Number": "5140151P0000000",
#         "Tunnel_Name": "FRYING PAN TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.39152908,
#         "Longitude": -82.77361,
#         "Year_Built": 1962,
#         "Year_Rehabilitated": 1985,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 50,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 582,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 363,
#         "Tunnel_Number": "5140152P0000000",
#         "Tunnel_Name": "DEVILS COURTHOUSE TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.30569458,
#         "Longitude": -82.89369,
#         "Year_Built": 1941,
#         "Year_Rehabilitated": 1986,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 35,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 721,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 364,
#         "Tunnel_Number": "5140153P0000000",
#         "Tunnel_Name": "PINNACLE RIDGE TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.43375015,
#         "Longitude": -83.03308,
#         "Year_Built": 1945,
#         "Year_Rehabilitated": 1962,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 35,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 859,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 365,
#         "Tunnel_Number": "5140154P0000000",
#         "Tunnel_Name": "LICKSTONE RIDGE TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.50780487,
#         "Longitude": -83.18761,
#         "Year_Built": 1946,
#         "Year_Rehabilitated": 1958,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 20,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 406,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 366,
#         "Tunnel_Number": "5140155P0000000",
#         "Tunnel_Name": "BUNCHES BALD TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.51380538,
#         "Longitude": -83.19278,
#         "Year_Built": 1947,
#         "Year_Rehabilitated": 1958,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 20,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 290,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 367,
#         "Tunnel_Number": "5140156P0000000",
#         "Tunnel_Name": "BIG WITCH TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.51783371,
#         "Longitude": -83.21484,
#         "Year_Built": 1947,
#         "Year_Rehabilitated": 1958,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 20,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 353,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 368,
#         "Tunnel_Number": "5140157P0000000",
#         "Tunnel_Name": "RATTLESNAKE MOUNTAIN TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.52022171,
#         "Longitude": -83.26908,
#         "Year_Built": 1958,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 20,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 415,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 369,
#         "Tunnel_Number": "5140158P0000000",
#         "Tunnel_Name": "SHERILL COVE TUNNEL",
#         "State_Code": "North Carolina",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.51239013,
#         "Longitude": -83.27084,
#         "Year_Built": 1958,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 1878,
#         "AADTT": 340.0,
#         "Detour Length": 20,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 590,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 370,
#         "Tunnel_Number": "5460003P0000000",
#         "Tunnel_Name": "CHIMNEY TOPS TUNNEL",
#         "State_Code": "Tennessee",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.63639068,
#         "Longitude": -83.47242,
#         "Year_Built": 1937,
#         "Year_Rehabilitated": 2001,
#         "Lanes": 2,
#         "AADT": 2364,
#         "AADTT": 0.0,
#         "Detour Length": 80,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 253,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 371,
#         "Tunnel_Number": "5460009P0000000",
#         "Tunnel_Name": "MORTON MOUNTAIN TUNNEL",
#         "State_Code": "Tennessee",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.61694335,
#         "Longitude": -83.42011,
#         "Year_Built": 1937,
#         "Year_Rehabilitated": 2002,
#         "Lanes": 2,
#         "AADT": 3388,
#         "AADTT": 0.0,
#         "Detour Length": 80,
#         "Toll": 0,
#         "NHS": 1,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 274,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 1
#     },
#     {
#         "Unnamed: 0": 372,
#         "Tunnel_Number": "5460016P0000000",
#         "Tunnel_Name": "BOTE MOUNTAIN TUNNEL",
#         "State_Code": "Tennessee",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 35.64958191,
#         "Longitude": -83.71525,
#         "Year_Built": 1948,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 3060,
#         "AADTT": 0.0,
#         "Detour Length": 50,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 121,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 373,
#         "Tunnel_Number": "7130005P0000000",
#         "Tunnel_Name": "RIO GRANDE OVERLOOK TUNNEL",
#         "State_Code": "Texas",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 29.20219421,
#         "Longitude": -102.9764,
#         "Year_Built": 1959,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 200,
#         "AADTT": 5.0,
#         "Detour Length": 199,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 301,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 0
#     },
#     {
#         "Unnamed: 0": 374,
#         "Tunnel_Number": "4290033P0000000",
#         "Tunnel_Name": "WILLIAMSBURG TUNNEL",
#         "State_Code": "Virginia",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 37.27313995,
#         "Longitude": -76.69928,
#         "Year_Built": 1942,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 5076,
#         "AADTT": 50.0,
#         "Detour Length": 1,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 1190,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 3
#     },
#     {
#         "Unnamed: 0": 375,
#         "Tunnel_Number": "4840004P0000000",
#         "Tunnel_Name": "MARYS ROCK TUNNEL",
#         "State_Code": "Virginia",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 38.65455627,
#         "Longitude": -78.31214,
#         "Year_Built": 1959,
#         "Year_Rehabilitated": 1993,
#         "Lanes": 2,
#         "AADT": 1400,
#         "AADTT": 0.0,
#         "Detour Length": 40,
#         "Toll": 1,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 583,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 376,
#         "Tunnel_Number": "5140133P0000000",
#         "Tunnel_Name": "BLUFF MOUNTAIN TUNNEL",
#         "State_Code": "Virginia",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 37.66561126,
#         "Longitude": -79.32198,
#         "Year_Built": 1957,
#         "Year_Rehabilitated": 1998,
#         "Lanes": 2,
#         "AADT": 474,
#         "AADTT": 0.0,
#         "Detour Length": 25,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 630,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 377,
#         "Tunnel_Number": "9450008P0000000",
#         "Tunnel_Name": "STEVENS CANYON ROAD TUNNEL #1",
#         "State_Code": "Washington",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 46.76338958,
#         "Longitude": -121.664,
#         "Year_Built": 1955,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 1500,
#         "AADTT": 225.0,
#         "Detour Length": 199,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 278,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 3
#     },
#     {
#         "Unnamed: 0": 378,
#         "Tunnel_Number": "9450023P0000000",
#         "Tunnel_Name": "STEVENS CANYON ROAD TUNNEL #2",
#         "State_Code": "Washington",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 46.76181411,
#         "Longitude": -121.6377,
#         "Year_Built": 1952,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 1500,
#         "AADTT": 225.0,
#         "Detour Length": 199,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 177,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 4
#     },
#     {
#         "Unnamed: 0": 379,
#         "Tunnel_Number": "9450041P0000000",
#         "Tunnel_Name": "SR 123 TUNNEL",
#         "State_Code": "Washington",
#         "Route_Type": "Federal Lands Road",
#         "Latitude": 46.84650039,
#         "Longitude": -121.527,
#         "Year_Built": 1935,
#         "Year_Rehabilitated": 0,
#         "Lanes": 2,
#         "AADT": 1500,
#         "AADTT": 225.0,
#         "Detour Length": 199,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 508,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 3
#     },
#     {
#         "Unnamed: 0": 380,
#         "Tunnel_Number": "6700001P0000000",
#         "Tunnel_Name": "TUNNEL #1",
#         "State_Code": "Nebraska",
#         "Route_Type": "Other",
#         "Latitude": 41.831501,
#         "Longitude": -103.7096,
#         "Year_Built": 1938,
#         "Year_Rehabilitated": 1990,
#         "Lanes": 2,
#         "AADT": 75,
#         "AADTT": 8.0,
#         "Detour Length": 199,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 145,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 381,
#         "Tunnel_Number": "6700002P0000000",
#         "Tunnel_Name": "TUNNEL #2",
#         "State_Code": "Nebraska",
#         "Route_Type": "Other",
#         "Latitude": 41.83286285,
#         "Longitude": -103.7098,
#         "Year_Built": 1938,
#         "Year_Rehabilitated": 1990,
#         "Lanes": 2,
#         "AADT": 75,
#         "AADTT": 8.0,
#         "Detour Length": 199,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 194,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 2
#     },
#     {
#         "Unnamed: 0": 382,
#         "Tunnel_Number": "6700003P0000000",
#         "Tunnel_Name": "TUNNEL #3",
#         "State_Code": "Nebraska",
#         "Route_Type": "Other",
#         "Latitude": 41.83552932,
#         "Longitude": -103.7084,
#         "Year_Built": 1938,
#         "Year_Rehabilitated": 1990,
#         "Lanes": 2,
#         "AADT": 75,
#         "AADTT": 8.0,
#         "Detour Length": 199,
#         "Toll": 0,
#         "NHS": 0,
#         "STRAHNET": 0,
#         "Class": "Minor Collector",
#         "Length": 166,
#         "Under_Nav_Water": 0,
#         "Number_Bores": 1,
#         "Tunnel_Shape": "Horseshoe",
#         "Ground_Conditions": "Rock",
#         "Condition": 3
#     }
# ]
