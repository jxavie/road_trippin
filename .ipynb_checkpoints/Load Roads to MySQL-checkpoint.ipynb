# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Config variables
from config import dbuser, dbpwd, dbhost, dbport, dbname

# Import Pandas
import pandas as pd

# %%
# Cloud MySQL Database Connection on AWS
engine = create_engine(f"mysql://{dbuser}:{dbpwd}@{dbhost}:{dbport}/{dbname}")

# %%
# Create a remote database engine connection
conn = engine.connect()

# %%
csv_data = pd.read_csv('Road/All_Road_Data.csv')
csv_data.head()
# Out:
#         State Location      System  Not_Reported      <60    60-94   95-119  \
# 0     Alabama    Rural  Interstate         3.338  409.293  103.533   22.363
# 1      Alaska    Rural  Interstate         0.000  203.573  330.051  151.728
# 2     Arizona    Rural  Interstate         1.513  537.675  223.363   78.487
# 3    Arkansas    Rural  Interstate         0.000  234.946  138.771   32.715
# 4  California    Rural  Interstate         8.534  519.824  369.451  143.799
#
#    120-144  145-170  171-194  195-220    >220
# 0   16.459    8.537    3.388    2.009   1.704
# 1  112.550   86.068   49.100   30.043  38.400
# 2   37.938   16.082   10.968    4.800   5.400
# 3   15.033    8.524    3.378    2.789   2.734
# 4   75.642   33.344   16.241    8.239  10.758

# %%
# Sum data up to state and location
del csv_data.System
df.groupby()

# %%
###compute ride quality summary score
#--------------
# <95  - Good (3)
# <170 - Acceptable (2)
# >170 - Bad (1)

csv_data['Ride_Quality'] = (3*(csv_data['<60']+csv_data['60-94']) +
                            2*(csv_data['95-119']+csv_data['120-144']+csv_data['145-170']) +
                            (csv_data['171-194']+csv_data['195-220']+csv_data['>220']))/(csv_data['<60']+csv_data['60-94']+
                                                                                         csv_data['95-119']+csv_data['120-144']+csv_data['145-170']+
                                                                                         csv_data['171-194']+csv_data['195-220']+csv_data['>220'])
# Out:
#         State Location      System  Not_Reported      <60    60-94   95-119  \
# 0     Alabama    Rural  Interstate         3.338  409.293  103.533   22.363
# 1      Alaska    Rural  Interstate         0.000  203.573  330.051  151.728
# 2     Arizona    Rural  Interstate         1.513  537.675  223.363   78.487
# 3    Arkansas    Rural  Interstate         0.000  234.946  138.771   32.715
# 4  California    Rural  Interstate         8.534  519.824  369.451  143.799
#
#    120-144  145-170  171-194  195-220    >220  Ride_Quality
# 0   16.459    8.537    3.388    2.009   1.704      2.891482
# 1  112.550   86.068   49.100   30.043  38.400      2.415452
# 2   37.938   16.082   10.968    4.800   5.400      2.808855
# 3   15.033    8.524    3.378    2.789   2.734      2.831224
# 4   75.642   33.344   16.241    8.239  10.758      2.725421

# %%
csv_data = csv_data.sort_values('Ride_Quality')
csv_data.head(20)
# Out:
#                     State Location                        System  \
# 203               Wyoming    Rural                Minor Arterial
# 314  District of Columbia    Urban      Other Principal Arterial
# 356               Wyoming    Urban      Other Principal Arterial
# 192          Rhode Island    Rural                Minor Arterial
# 345          Rhode Island    Urban      Other Principal Arterial
# 152               Wyoming    Rural      Other Principal Arterial
# 212  District of Columbia    Urban                    Interstate
# 310            California    Urban      Other Principal Arterial
