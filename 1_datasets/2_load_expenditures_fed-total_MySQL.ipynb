# %%
# !pip install sqlalchemy
# !pip install pymysql

# %%
# SQL Alchemy
from sqlalchemy import create_engine

# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

# Config variables
import sys
sys.path.append('..')
from config import remote_gwsis_dbuser, remote_gwsis_dbpwd, remote_db_host, remote_db_port, remote_gwsis_dbname

# Import Pandas
import pandas as pd

# %%
# Cloud MySQL Database Connection on AWS
engine = create_engine(f"mysql://{remote_gwsis_dbuser}:{remote_gwsis_dbpwd}@{remote_db_host}:{remote_db_port}/{remote_gwsis_dbname}")

# %%
# Create a remote database engine connection
conn = engine.connect()

# %% [markdown]
# ### expenditures_percent-gdp_2017dollars

# %%
csv_data = pd.read_csv('expenditures/federal_v_state/2_cleaned/expenditures_percent-gdp_2017dollars.csv')
# csv_data = csv_data.set_index("Unnamed: 0")
# del csv_data.index.name
csv_data.head()
# Out:
#    Year  Federal (Billions of 2017 Dollars)  \
# 0  1962                           19.191182
# 1  1963                           20.289410
# 2  1964                           23.757861
# 3  1965                           25.636076
# 4  1966                           24.841447
#
#    State and Local (Billions of 2017 Dollars)  Federal (% GDP)  \
# 0                                   29.547723            0.510
# 1                                   31.336128            0.518
# 2                                   29.599462            0.573
# 3                                   29.684392            0.586
# 4                                   30.785549            0.527
#
#    State and Local (% GDP)
# 0                    0.785
# 1                    0.800
# 2                    0.714
# 3                    0.678
# 4                    0.653

# %%
csv_data.to_sql(name='spending_fedstate_percentgdp', if_exists='append', con=conn, chunksize=500, index=False)

# %% [markdown]
# ### fed_expenditures_2017dollars

# %%
csv_data = pd.read_csv('expenditures/federal_v_state/2_cleaned/fed_expenditures_2017dollars.csv')
# csv_data = csv_data.set_index("Unnamed: 0")
# del csv_data.index.name
csv_data.head()
# Out:
#    Year  All (Total)  All (Capital)  All (O&M)  Highways (Total)  \
# 0  1956        21635          16211       5424             10206
# 1  1957        25008          18886       6122             12372
# 2  1958        33013          28150       4862             19231
# 3  1959        52007          44194       7813             33416
# 4  1960        58568          50215       8353             38899
#
#    Highways (Capital)  Highways (O&M)  Mass Transit (Total)  \
# 0                9695             511                     0
# 1               11884             488                     0
# 2               19037             194                     0
# 3               33094             321                     0
# 4               38413             486                     0
#
#    Mass Transit (Capital)  Mass Transit (O&M)  ...  Aviation (O&M)  \
# 0                       0                   0  ...            1663
# 1                       0                   0  ...            1843
# ...

# %%
csv_data.to_sql(name='spending_fed_2017dollars', if_exists='append', con=conn, chunksize=500, index=False)

# %% [markdown]
# ### state_expenditures_totals_2017dollars

# %%
csv_data = pd.read_csv('expenditures/federal_v_state/2_cleaned/state_expenditures_totals_2017dollars.csv')
# csv_data = csv_data.set_index("Unnamed: 0")
# del csv_data.index.name
csv_data.head()
# Out:
#    Year  All (Total)  All (Capital)  All (O&M)  Highways (Total)  \
# 0  1956       137628          80678      56950             95622
# 1  1957       145322          84656      60666            101725
# 2  1958       155625          93409      62216            110625
# 3  1959       172713         107882      64831            123391
# 4  1960       172618         106459      66158            122705
#
#    Highways (Capital)  Highways (O&M)  Mass Transit (Total)  \
# 0               61892           33729                  8328
# 1               65185           36540                  8136
# 2               72582           38043                  8319
# 3               84498           38893                  8438
# 4               83204           39501                  8714
#
#    Mass Transit (Capital)  Mass Transit (O&M)  ...  Aviation (O&M)  \
# 0                    1415                6913  ...             763
# 1                    1459                6677  ...             898
# ...

# %%
csv_data.to_sql(name='spending_state_2017dollars', if_exists='append', con=conn, chunksize=500, index=False)

# %% [markdown]
# ### total-fed-state_expenditures_2017dollars

# %%
csv_data = pd.read_csv('expenditures/federal_v_state/2_cleaned/total-fed-state_expenditures_2017dollars.csv')
# csv_data = csv_data.set_index("Unnamed: 0")
# del csv_data.index.name
csv_data.head()
# Out:
#    Year  All (Total)  All (Capital)  All (O&M)  Highways (Total)  \
# 0  1956       149186          86813      62373             96133
# 1  1957       157985          91253      66732            102157
# 2  1958       168629         101645      66983            110724
# 3  1959       190156         117671      72486            123554
# 4  1960       191103         116783      74319            122999
#
#    Highways (Capital)  Highways (O&M)  Mass Transit (Total)  \
# 0               61892           34240                  8328
# 1               65185           36972                  8136
# 2               72582           38142                  8319
# 3               84498           39057                  8438
# 4               83204           39795                  8714
#
#    Mass Transit (Capital)  Mass Transit (O&M)  ...  Aviation (O&M)  \
# 0                    1415                6913  ...            2426
# 1                    1459                6677  ...            2741
# ...

# %%
csv_data.to_sql(name='spending_fedstate_2017dollars', if_exists='append', con=conn, chunksize=500, index=False)
