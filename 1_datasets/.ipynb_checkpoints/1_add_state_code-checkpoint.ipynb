# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# assign federal dataset path to variable
csv_path = "geojson/state_code.csv"

# load csv
state_codes = pd.read_csv(csv_path, encoding="utf8")
state_codes.head(1)
# Out:
#   State/District Postal Code
# 0        Alabama          AL

# %%
# assign federal dataset path to variable
csv_path = "bridge/Bridge_Data_Cleaned.csv"

# load csv
bridge_data = pd.read_csv(csv_path, encoding="utf8")
bridge_data.head(1)
# Out:
# C:\Users\jnjav\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    ID State_Code        Features_Intersected      Facility_Carried      Lat  \
# 0   1    Alabama  '           PERDIDO CREEK'  '  IRR BIA RTE 4007'  31.1031
#
#       Long  Year_Built  Avg_Daily_Traffic        Structure_Kind  \
# 0  87.5704      1999.0               50.0  Prestressed concrete
#
#                    Structure_Type  Length  Improvement_Cost  \
# 0  Box beam or girders - Multiple    15.0               0.0
#
#    Year_Reconstructed      Deck_Strucutre_Type Surface_Type Membrane_Type  \
# 0                 0.0  Concrete Precast Panels   Bituminous          None
#
#             Deck_Protection  Percent_Truck_Traffic            Score  \
# 0  Epoxy Coated Reinforcing                    1.0  Good Condition
#
# ...

# %%
for i in range(0,5):
# for i in range(0,len(bridge_data)):
    
    df_name = bridge_data['State_Code'][i].lower()
    print(df_name)
    
    for j in range(0,len(state_codes)):
        name = state_codes["State/District"][j].lower()
        code = state_codes["Postal Code"][j]
        
        
        if df_name == name:
            bridge_data['State_Abbreviation'][i] = code
            print(name)
            print(code)

bridge_data.head()
# Out:
# alabama
# alabama
# AL
# idaho
# idaho
# ID
# idaho
# idaho
# ID
# illinois
# illinois
# IL
# indiana
# indiana
# IN
# C:\Users\jnjav\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#    ID State_Code        Features_Intersected      Facility_Carried      Lat  \
# 0   1    Alabama  '           PERDIDO CREEK'  '  IRR BIA RTE 4007'  31.1031
# 1   2      Idaho  'MORA CANAL              '  'CAN-ADA ROAD      '  43.4514
# 2   3      Idaho  'PHYLLIS CANAL           '  'CHISHOLM DRIVE    '  43.5989
# 3   4   Illinois  'STREAM                  '  'REINKING ROAD     '    42.08
# 4   5    Indiana  'BRANCH OF ROCK CREEK    '  'CR 900 E          '  39.1432
#
#       Long  Year_Built  Avg_Daily_Traffic        Structure_Kind  \
# ...

# %%
# export modified json file
# state_geo.to_json("../data/infrastructure_condition_2018.json")
