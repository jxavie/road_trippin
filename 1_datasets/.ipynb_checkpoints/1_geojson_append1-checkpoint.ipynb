# %%
# import dependencies
import pandas as pd
import numpy as np
import json
from pandas.io.json import json_normalize

# %%
# assign federal dataset path to variable
json_path = "geojson/gz_2010_us_040_00_5m.json"

# load csv
state_geo = pd.read_json(json_path, encoding="utf8")
state_geo
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 1   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 2   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 4   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 5   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 6   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 7   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 8   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 9   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 10  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 11  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 12  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 13  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 14  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 15  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 16  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 17  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 18  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 19  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 20  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 21  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 22  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 23  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 24  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 25  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 26  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 27  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 28  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 29  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 30  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 31  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 32  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 33  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 34  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 35  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 36  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 37  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 38  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 39  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 40  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 41  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 42  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 43  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 44  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 45  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 46  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 47  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 48  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 49  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 50  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 51  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...

# %%
# assign features list to a variable
features = state_geo['features']

# normalize for ease of view
json_normalize(features)
# Out:
#                                  geometry.coordinates geometry.type  \
# 0   [[[[-88.124658, 30.28364], [-88.086812, 30.259...  MultiPolygon
# 1   [[[[-166.10574, 53.988606], [-166.075283, 53.9...  MultiPolygon
# 2   [[[-112.538593, 37.000674], [-112.534545, 37.0...       Polygon
# 3   [[[-94.042964, 33.019219], [-94.043036, 33.079...       Polygon
# 4   [[[[-122.421439, 37.869969], [-122.421341, 37....  MultiPolygon
# 5   [[[-106.190554, 40.997607], [-106.061181, 40.9...       Polygon
# 6   [[[-71.799242, 42.008065], [-71.797922, 41.935...       Polygon
# 7   [[[[-75.564927, 39.583248], [-75.576271, 39.58...  MultiPolygon
# 8   [[[-77.038598, 38.791513], [-77.038898, 38.800...       Polygon
# 9   [[[[-82.821585, 27.964443], [-82.829801, 27.96...  MultiPolygon
# 10  [[[-84.810477, 34.987607], [-84.809184, 34.987...       Polygon
# 11  [[[[-155.778234, 20.245743], [-155.772734, 20....  MultiPolygon
# 12  [[[-111.044156, 43.020052], [-111.044129, 43.0...       Polygon
# 13  [[[-89.366031, 42.500274], [-89.361561, 42.500...       Polygon
# 14  [[[-84.802483, 40.528046], [-84.802547, 40.501...       Polygon
# 15  [[[-91.217706, 43.50055], [-91.21827, 43.49722...       Polygon
# 16  [[[-99.541116, 36.999573], [-99.558068, 36.999...       Polygon
# 17  [[[[-89.485106, 36.497692], [-89.492537, 36.49...  MultiPolygon
# 18  [[[[-88.865067, 29.752714], [-88.889755, 29.71...  MultiPolygon
# 19  [[[[-70.152589, 43.746794], [-70.151959, 43.74...  MultiPolygon
# 20  [[[[-76.048373, 38.12055], [-76.056811, 38.125...  MultiPolygon
# 21  [[[[-70.827398, 41.602067], [-70.823735, 41.59...  MultiPolygon
# 22  [[[[-85.825955, 45.404296], [-85.833516, 45.37...  MultiPolygon
# 23  [[[-92.204691, 46.704041], [-92.205692, 46.702...       Polygon
# 24  [[[[-89.095623, 30.231767], [-89.077259, 30.23...  MultiPolygon
# 25  [[[-89.545006, 36.336809], [-89.560439, 36.337...       Polygon
# 26  [[[-105.038405, 45.000345], [-105.076607, 45.0...       Polygon
# 27  [[[-104.053249, 41.001406], [-104.053158, 41.0...       Polygon
# 28  [[[-114.042145, 40.999926], [-114.043176, 40.7...       Polygon
# 29  [[[-72.4521, 43.161414], [-72.451868, 43.17017...       Polygon
# 30  [[[-75.210876, 39.865709], [-75.210425, 39.865...       Polygon
# 31  [[[-105.998003, 32.002328], [-106.099756, 32.0...       Polygon
# 32  [[[[-74.04086, 40.700117], [-74.040018, 40.700...  MultiPolygon
# 33  [[[[-75.753765, 35.199612], [-75.74522, 35.203...  MultiPolygon
# 34  [[[-98.724375, 45.938686], [-98.904429, 45.939...       Polygon
# 35  [[[[-82.835118, 41.708971], [-82.82572, 41.722...  MultiPolygon
# 36  [[[-96.944611, 33.949217], [-96.952313, 33.944...       Polygon
# 37  [[[-121.922236, 45.649083], [-121.908267, 45.6...       Polygon
# 38  [[[-79.916171, 39.720893], [-80.075947, 39.721...       Polygon
# 39  [[[[-71.383586, 41.464782], [-71.389284, 41.46...  MultiPolygon
# 40  [[[-79.290754, 33.110051], [-79.291591, 33.109...       Polygon
# 41  [[[-104.054487, 44.180381], [-104.055389, 44.2...       Polygon
# 42  [[[-83.472108, 36.597284], [-83.374904, 36.597...       Polygon
# 43  [[[[-97.134356, 27.896329], [-97.1336, 27.8974...  MultiPolygon
# 44  [[[-111.046551, 41.251716], [-111.046723, 40.9...       Polygon
# 45  [[[-72.433796, 43.232999], [-72.434466, 43.230...       Polygon
# 46  [[[[-75.973607, 37.835817], [-75.971705, 37.83...  MultiPolygon
# 47  [[[[-122.519535, 48.288314], [-122.522756, 48....  MultiPolygon
# 48  [[[-80.075947, 39.72135], [-79.916171, 39.7208...       Polygon
# 49  [[[[-90.403306, 47.026693], [-90.403321, 47.02...  MultiPolygon
# 50  [[[-110.048476, 40.997555], [-110.121639, 40.9...       Polygon
# 51  [[[[-65.3277, 18.295843], [-65.337451, 18.3083...  MultiPolygon
#
#     properties.CENSUSAREA properties.GEO_ID properties.LSAD  \
# 0               50645.326       0400000US01
# 1              570640.950       0400000US02
# 2              113594.084       0400000US04
# 3               52035.477       0400000US05
# 4              155779.220       0400000US06
# 5              103641.888       0400000US08
# 6                4842.355       0400000US09
# 7                1948.543       0400000US10
# 8                  61.048       0400000US11
# 9               53624.759       0400000US12
# 10              57513.485       0400000US13
# 11               6422.628       0400000US15
# 12              82643.117       0400000US16
# 13              55518.930       0400000US17
# 14              35826.109       0400000US18
# 15              55857.130       0400000US19
# 16              81758.717       0400000US20
# 17              39486.338       0400000US21
# 18              43203.905       0400000US22
# 19              30842.923       0400000US23
# 20               9707.241       0400000US24
# 21               7800.058       0400000US25
# 22              56538.901       0400000US26
# 23              79626.743       0400000US27
# 24              46923.274       0400000US28
# 25              68741.522       0400000US29
# 26             145545.801       0400000US30
# 27              76824.171       0400000US31
# 28             109781.180       0400000US32
# 29               8952.651       0400000US33
# 30               7354.220       0400000US34
# 31             121298.148       0400000US35
# 32              47126.399       0400000US36
# 33              48617.905       0400000US37
# 34              69000.798       0400000US38
# 35              40860.694       0400000US39
# 36              68594.921       0400000US40
# 37              95988.013       0400000US41
# 38              44742.703       0400000US42
# 39               1033.814       0400000US44
# 40              30060.696       0400000US45
# 41              75811.000       0400000US46
# 42              41234.896       0400000US47
# 43             261231.711       0400000US48
# 44              82169.620       0400000US49
# 45               9216.657       0400000US50
# 46              39490.086       0400000US51
# 47              66455.521       0400000US53
# 48              24038.210       0400000US54
# 49              54157.805       0400000US55
# 50              97093.141       0400000US56
# 51               3423.775       0400000US72
#
#          properties.NAME properties.STATE     type
# 0                Alabama               01  Feature
# 1                 Alaska               02  Feature
# 2                Arizona               04  Feature
# 3               Arkansas               05  Feature
# 4             California               06  Feature
# 5               Colorado               08  Feature
# 6            Connecticut               09  Feature
# 7               Delaware               10  Feature
# 8   District of Columbia               11  Feature
# 9                Florida               12  Feature
# 10               Georgia               13  Feature
# 11                Hawaii               15  Feature
# 12                 Idaho               16  Feature
# 13              Illinois               17  Feature
# 14               Indiana               18  Feature
# 15                  Iowa               19  Feature
# 16                Kansas               20  Feature
# 17              Kentucky               21  Feature
# 18             Louisiana               22  Feature
# 19                 Maine               23  Feature
# 20              Maryland               24  Feature
# 21         Massachusetts               25  Feature
# 22              Michigan               26  Feature
# 23             Minnesota               27  Feature
# 24           Mississippi               28  Feature
# 25              Missouri               29  Feature
# 26               Montana               30  Feature
# 27              Nebraska               31  Feature
# 28                Nevada               32  Feature
# 29         New Hampshire               33  Feature
# 30            New Jersey               34  Feature
# 31            New Mexico               35  Feature
# 32              New York               36  Feature
# 33        North Carolina               37  Feature
# 34          North Dakota               38  Feature
# 35                  Ohio               39  Feature
# 36              Oklahoma               40  Feature
# 37                Oregon               41  Feature
# 38          Pennsylvania               42  Feature
# 39          Rhode Island               44  Feature
# 40        South Carolina               45  Feature
# 41          South Dakota               46  Feature
# 42             Tennessee               47  Feature
# 43                 Texas               48  Feature
# 44                  Utah               49  Feature
# 45               Vermont               50  Feature
# 46              Virginia               51  Feature
# 47            Washington               53  Feature
# 48         West Virginia               54  Feature
# 49             Wisconsin               55  Feature
# 50               Wyoming               56  Feature
# 51           Puerto Rico               72  Feature

# %%
# assign bridge condition summary dataset path to variable
csv_path = "bridge/condition_by-hwy-sys_all_1.csv"

# load csv
bridge_df = pd.read_csv(csv_path)

# filter for 2018 data only; remove entries for Guam and Totals
data_2018 = bridge_df.loc[bridge_df["Year"] == 2018]
data_2018 = data_2018.loc[data_2018["State"] != "GUAM"]
data_2018 = data_2018.loc[data_2018["State"] != "TOTALS"]
data_2018
# Out:
#     ID  Year           State  Count_All  Count_Good  Count_Fair  Count_Poor  \
# 0    1  2018         ALABAMA      16130        6838        8603         689
# 1    2  2018          ALASKA       1592         711         725         155
# 2    3  2018         ARIZONA       8294        5068        3076         150
# 3    4  2018        ARKANSAS      12892        6816        5488         588
# 4    5  2018      CALIFORNIA      25737       14779        9146        1812
# 5    6  2018        COLORADO       8786        3694        4618         473
# 6    7  2018     CONNECTICUT       4270        1238        2724         308
# 7    8  2018        DELAWARE        863         195         634          34
# 8    9  2018   DIST. OF COL.        244          62         174           8
# 9   10  2018         FLORIDA      12435        8389        3717         328
# 10  11  2018         GEORGIA      14879        6303        8082         494
# 11  12  2018          HAWAII       1137         355         704          78
# 12  13  2018           IDAHO       4482        1259        2907         315
# 13  14  2018        ILLINOIS      26809       13438       11098        2273
# 14  15  2018         INDIANA      19280        7959       10114        1203
# 15  16  2018            IOWA      24123        9180       10263        4675
# 16  17  2018          KANSAS      24906       13594       10024        1288
# 17  18  2018        KENTUCKY      14368        5239        8111        1016
# 18  19  2018       LOUISIANA      12899        6484        4733        1678
# 19  20  2018           MAINE       2473         786        1362         325
# 20  21  2018        MARYLAND       5357        1757        3326         274
# 21  22  2018   MASSACHUSETTS       5215        1370        3364         481
# 22  23  2018        MICHIGAN      11228        4479        5548        1196
# 23  24  2018       MINNESOTA      13358        8259        4431         668
# 24  25  2018     MISSISSIPPI      17071       10711        4757        1603
# 25  26  2018        MISSOURI      24512       10579       11817        2116
# 26  27  2018         MONTANA       5265        1605        3270         390
# 27  28  2018        NEBRASKA      15349        7985        6003        1358
# 28  29  2018          NEVADA       1979         978         974          27
# 29  30  2018   NEW HAMPSHIRE       2494        1323         947         224
# 30  31  2018      NEW JERSEY       6746        1819        4383         544
# 31  32  2018      NEW MEXICO       4010        1519        2259         232
# 32  33  2018        NEW YORK      17521        6400        9364        1757
# 33  34  2018  NORTH CAROLINA      18377        7186        9313        1871
# 34  35  2018    NORTH DAKOTA       4355        2341        1545         469
# 35  36  2018            OHIO      27277       15974        9785        1518
# 36  37  2018        OKLAHOMA      23116       10304       10268        2540
# 37  38  2018          OREGON       8161        2881        4858         422
# 38  39  2018    PENNSYLVANIA      22737        6985       11979        3770
# 39  40  2018    RHODE ISLAND        780         134         466         180
# 40  41  2018  SOUTH CAROLINA       9401        4225        4381         795
# 41  42  2018    SOUTH DAKOTA       5824        1906        2945         973
# 42  43  2018       TENNESSEE      20177        9221       10084         871
# 43  44  2018           TEXAS      54131       28020       25411         695
# 44  45  2018            UTAH       3061        1659        1336          66
# 45  46  2018         VERMONT       2778        1473        1239          66
# 46  47  2018        VIRGINIA      13931        4786        8499         646
# 47  48  2018      WASHINGTON       8278        4317        3579         382
# 48  49  2018   WEST VIRGINIA       7269        1978        3844        1444
# 49  50  2018       WISCONSIN      14275        7383        5838        1054
# 50  51  2018         WYOMING       3129         926        1946         257
# 51  53  2018     PUERTO RICO       2325         444        1608         273
#
#     Area_All  Area_Good  Area_Fair  ...  Tunnel_Percentage_Severe  \
# 0    9760735    3661978    5851785  ...                  0.000106
# 1     743788     298515     385915  ...                  0.041263
# 2    5846176    3169212    2581507  ...                  0.001802
# 3    6708589    3475609    2919170  ...                  0.000003
# 4   30067631   17623112   10442456  ...                  0.013273
# 5    5024622    2359789    2457413  ...                  0.001999
# 6    3414833     600502    2406635  ...                  0.000282
# 7    1000357     141858     800016  ...                  0.000000
# 8     569296      75891     470820  ...                  0.000523
# 9   17516213   11658699    5575956  ...                  0.000043
# 10  10082064    4640184    5205927  ...                  0.000048
# 11   1324180     326663     968926  ...                  0.000001
# 12   1756871     442282    1229647  ...                  0.032900
# 13  13524885    5027056    6999849  ...                  0.000000
# 14   8197646    3735606    4134643  ...                  0.003821
# 15   8806907    4044915    3872593  ...                  0.000000
# 16   8680998    5693563    2743165  ...                  0.000000
# 17   6509802    2480985    3717280  ...                  0.000232
# 18  16587147    7752468    7449875  ...                  0.001262
# 19   1264519     451266     708474  ...                  0.000000
# 20   5426511    1602956    3648777  ...                  0.001049
# 21   4119863     869419    2766279  ...                  0.001606
# 22   6445678    2281475    3564054  ...                  0.036192
# 23   7132639    3859452    3022860  ...                  0.000090
# 24   9940070    6504401    3019248  ...                  0.000000
# 25  10701764    4325670    5466291  ...                  0.000008
# 26   2084807     459891    1463582  ...                  0.045302
# 27   4340537    2586969    1528921  ...                  0.000000
# 28   1791492     838231     939426  ...                  0.000285
# 29   1130225     631927     404980  ...                  0.000000
# 30   7002430    1654510    4852975  ...                  0.001839
# 31   2080960     750052    1230457  ...                  0.000000
# 32  13089606    3596940    8164313  ...                  0.006482
# 33   9994006    4051533    5028174  ...                  0.000112
# 34   1320937     770811     482267  ...                  0.000000
# 35  13956582    8043801    5430710  ...                  0.000355
# 36   8738610    4203648    3991370  ...                  0.000000
# 37   5060329    1043269    3829407  ...                  0.000028
# 38  13945241    3817119    8956109  ...                  0.000208
# 39    793527     109894     493870  ...                  0.319536
# 40   6985851    3191638    3339881  ...                  0.000000
# 41   1803770     517279    1142586  ...                  0.083018
# 42  10275911    4306805    5561752  ...                  0.004770
# 43  50368715   26200337   23665660  ...                  0.000010
# 44   1948005    1013841     919942  ...                  0.000017
# 45    884043     451405     404534  ...                  0.000000
# 46  10125635    3560099    6146720  ...                  0.000713
# 47   7224042    2790592    3893877  ...                  0.000303
# 48   3811742     743138    2535381  ...                  0.012393
# 49   7006791    3677689    3034479  ...                  0.000000
# 50   1339545     317802     900448  ...                  0.002025
# 51   2180690     459866    1525035  ...                  0.000000
#
#      Road_Total  Road_Not_Reported  Road_Road_Good_below95  Road_Fair_95to170  \
# 0    8345.55725           42.07674              6691.66651         1211.77700
# 1    2436.94823          404.07334               900.09878          500.26404
# 2    4668.39580          293.60551              2779.42131         1047.86457
# 3    6472.53981           43.91334              3670.73899         1787.29381
# 4   20302.04369          112.00273              7727.29092         5296.97070
# 5    8416.97253          292.14165              3966.38527         2596.11607
# 6    1677.32807            0.27172               776.03407          520.82493
# 7     500.87859            3.55687               314.43428          122.10804
# 8     133.86100            0.12500                 3.40600           18.83200
# 9   11021.73667           17.56798              8531.28510         1872.60256
# 10  12190.23568         1650.04420              8143.70733         1841.13040
# 11    691.67000            1.42000               195.16900          226.35900
# 12   3967.99987          340.78243              2654.56765          723.41148
# 13  12318.03017           25.42000              6742.78994         3555.59328
# 14   7427.28897          699.95490              4483.88898         1529.86011
# 15   5125.28376           95.36876              2952.50200         1307.47700
# 16   8673.25457           36.70533              7011.34885         1275.14805
# 17   5605.21103           64.99903              3847.00026         1290.76068
# 18   5037.27786          161.20704              2271.19515         1481.47304
# 19   2253.80800            5.46100              1365.09700          498.70000
# 20   2920.05176           26.80334              1871.65831          544.90628
# 21   3292.65681           30.89643              1284.03238          744.62215
# 22  11322.30921           62.13961              7180.33345         2405.39142
# 23  11692.47107           18.53516              7211.29516         2941.60217
# 24   7416.30245           35.00645              4268.69052         1868.49773
# 25   9769.67309           32.58728              5974.73704         2673.67343
# 26   7081.57227           11.89117              4850.72435         1595.85381
# 27   7549.25896          350.18852              5479.01031         1033.80483
# 28   3291.20628           28.20394              2707.80882          426.50521
# 29   1482.88402            3.77772              1043.83596          195.63154
# 30   3163.66836            3.01805              1383.69760          681.68990
# 31   5932.72365           41.05922              3272.60936         1361.96361
# 32  10837.40770          272.66056              5057.83778         2938.37955
# 33   8418.02759           86.49092              5162.87684         2118.49599
# 34   6252.48030            5.82633              4875.11712         1018.31568
# 35   9128.45516           28.15468              5837.90755         1913.04572
# 36   4631.04522          747.98768              2415.25831          947.77701
# 37   6506.14921           12.81655              4116.36635         1883.55570
# 38  11623.71675           18.55770              5613.46752         3688.69516
# 39    624.53844           20.75057               149.66000          139.76222
# 40   6591.50680           17.88049              3704.17785         2098.31313
# 41   6626.03358           50.11042              4001.51957         1844.24999
# 42   5146.65293          203.50228              3736.22941          786.09464
# 43  20235.09604          261.93392             11651.48818         5069.13916
# 44   4128.19285           12.70427              2542.94788         1150.00620
# 45   1530.25338            9.03369              1023.10478          327.87622
# 46   8126.95012           38.55602              4610.93642         2675.59929
# 47   6588.83109           32.62911              3219.97277         1842.48359
# 48   3335.09961           30.40148              1700.45427         1105.57443
# 49  10873.22564           25.82200              5493.08890         2812.22300
# 50   1696.02979           33.12200               763.16700          251.19324
# 51      0.00000            0.00000                 0.00000            0.00000
#
#     Road_Poor_above170  Road_NotReported_Percentage  Road_Good_Percentage  \
# 0            220.39271                     0.504181             80.182381
# 1            436.10563                    16.581121             36.935490
# 2            289.53975                     6.289216             59.536968
# 3            502.15671                     0.678456             56.712498
# 4           5005.21738                     0.551682             38.061641
# 5            937.00781                     3.470864             47.123657
# 6            234.82630                     0.016200             46.266087
# 7             39.56467                     0.710126             62.776546
# 8            111.36500                     0.093380              2.544430
# 9            320.18109                     0.159394             77.404182
# 10           284.34236                    13.535786             66.805167
# 11           167.59800                     0.205300             28.217069
# 12           111.87102                     8.588267             66.899389
# 13          1130.71753                     0.206364             54.739190
# 14           397.29234                     9.424097             60.370466
# 15           470.99500                     1.860751             57.606606
# 16           177.65511                     0.423201             80.838730
# 17           207.06101                     1.159618             68.632568
# 18           692.43044                     3.200281             45.087748
# 19           254.67000                     0.242301             60.568469
# 20           345.37242                     0.917906             64.096751
# 21           899.95182                     0.938343             38.996848
# 22          1104.13088                     0.548825             63.417571
# 23           894.65814                     0.158522             61.674689
# 24           711.67987                     0.472020             57.558204
# 25           550.97050                     0.333555             61.155957
# 26           345.73368                     0.167917             68.497844
# 27           438.94634                     4.638714             72.576796
# 28            63.94607                     0.856948             82.274054
# 29           183.21678                     0.254755             70.392286
# 30           826.27933                     0.095397             43.737125
# 31           839.98365                     0.692080             55.162006
# 32          1824.48770                     2.515920             46.670181
# 33           594.45486                     1.027449             61.331194
# 34           208.95725                     0.093184             77.970931
# 35           899.78660                     0.308428             63.952853
# 36           305.59984                    16.151595             52.153633
# 37           282.76816                     0.196991             63.268859
# 38          1446.44950                     0.159654             48.293224
# 39           237.70636                     3.322545             23.963297
# 40           362.06600                     0.271266             56.196223
# 41           369.17445                     0.756266             60.390874
# 42           256.13660                     3.954070             72.595325
# 43          2123.22260                     1.294454             57.580592
# 44           204.26975                     0.307744             61.599542
# 45            97.33748                     0.590339             66.858521
# 46           380.92071                     0.474422             56.736369
# 47          1006.87382                     0.495218             48.870167
# 48           275.97335                     0.911561             50.986611
# 49          1638.99128                     0.237482             50.519405
# 50           536.95315                     1.952914             44.997264
# 51             0.00000                     0.000000              0.000000
#
#     Road_Fair_Percentage  Road_Poor_Percentage
# 0              14.520025              2.640839
# 1              20.528300             17.895564
# 2              22.445924              6.202125
# 3              27.613485              7.758264
# 4              26.090825             24.653761
# 5              30.843823             11.132362
# 6              31.050868             14.000022
# 7              24.378770              7.899054
# 8              14.068325             83.194508
# 9              16.990086              2.904997
# 10             15.103321              2.332542
# 11             32.726445             24.230919
# 12             18.231137              2.819330
# 13             28.864950              9.179370
# 14             20.597827              5.349090
# 15             25.510334              9.189638
# 16             14.702071              2.048310
# 17             23.027869              3.694081
# 18             29.410191             13.746124
# 19             22.126996             11.299543
# 20             18.660843             11.827613
# 21             22.614630             27.332087
# 22             21.244707              9.751817
# 23             25.158088              7.651575
# 24             25.194465              9.596155
# 25             27.367072              5.639600
# 26             22.535304              4.882160
# 27             13.694123              5.814430
# 28             12.958933              1.942937
# 29             13.192639             12.355436
# 30             21.547451             26.117761
# 31             22.956802             14.158483
# 32             27.113306             16.835093
# 33             25.166180              7.061688
# 34             16.286588              3.341990
# 35             20.956949              9.856943
# 36             20.465726              6.598939
# 37             28.950392              4.346168
# 38             31.734214             12.443950
# 39             22.378482             38.061126
# 40             31.833588              5.492917
# 41             27.833393              5.571575
# 42             15.273900              4.976761
# 43             25.051224             10.492773
# 44             27.857376              4.948164
# 45             21.426270              6.360873
# 46             32.922551              4.687130
# 47             27.963740             15.281524
# 48             33.149667              8.274816
# 49             25.863742             15.073644
# 50             14.810662             31.659417
# 51              0.000000              0.000000
#
# [52 rows x 35 columns]

# %%
data_2018["Tunnel_Percentage_Good"] = (data_2018["Tunnel_Percentage_Good"] *100).map("{:.2f}%".format)
data_2018["Tunnel_Percentage_Fair"] = (data_2018["Tunnel_Percentage_Fair"] *100).map("{:.2f}%".format)
data_2018["Tunnel_Percentage_Poor"] = (data_2018["Tunnel_Percentage_Poor"] *100).map("{:.2f}%".format)
data_2018["Tunnel_Percentage_Severe"] = (data_2018["Tunnel_Percentage_Severe"] *100).map("{:.2f}%".format)
data_2018["Area_Percentage_Good"] = (data_2018["Area_Percentage_Good"] *100).map("{:.2f}%".format)
data_2018["Area_Percentage_Fair"] = (data_2018["Area_Percentage_Fair"] *100).map("{:.2f}%".format)
data_2018["Area_Percentage_Poor"] = (data_2018["Area_Percentage_Poor"] *100).map("{:.2f}%".format)
data_2018["Percentage_Good"] = (data_2018["Percentage_Good"] *100).map("{:.2f}%".format)
data_2018["Percentage_Fair"] = (data_2018["Percentage_Fair"] *100).map("{:.2f}%".format)
data_2018["Percentage_Poor"] = (data_2018["Percentage_Poor"] *100).map("{:.2f}%".format)
data_2018["Road_NotReported_Percentage"] =(data_2018["Road_NotReported_Percentage"]).map("{:.2f}%".format)
data_2018["Road_Good_Percentage"] =(data_2018["Road_Good_Percentage"]).map("{:.2f}%".format)
data_2018["Road_Fair_Percentage"] =(data_2018["Road_Fair_Percentage"]).map("{:.2f}%".format)
data_2018["Road_Poor_Percentage"] =(data_2018["Road_Poor_Percentage"]).map("{:.2f}%".format)
data_2018.head()
# Out:
#    ID  Year       State  Count_All  Count_Good  Count_Fair  Count_Poor  \
# 0   1  2018     ALABAMA      16130        6838        8603         689
# 1   2  2018      ALASKA       1592         711         725         155
# 2   3  2018     ARIZONA       8294        5068        3076         150
# 3   4  2018    ARKANSAS      12892        6816        5488         588
# 4   5  2018  CALIFORNIA      25737       14779        9146        1812
#
#    Area_All  Area_Good  Area_Fair  ...  Tunnel_Percentage_Severe   Road_Total  \
# 0   9760735    3661978    5851785  ...                     0.01%   8345.55725
# 1    743788     298515     385915  ...                     4.13%   2436.94823
# 2   5846176    3169212    2581507  ...                     0.18%   4668.39580
# 3   6708589    3475609    2919170  ...                     0.00%   6472.53981
# 4  30067631   17623112   10442456  ...                     1.33%  20302.04369
#
#   Road_Not_Reported Road_Road_Good_below95 Road_Fair_95to170  \
# 0          42.07674             6691.66651        1211.77700
# 1         404.07334              900.09878         500.26404
# 2         293.60551             2779.42131        1047.86457
# 3          43.91334             3670.73899        1787.29381
# 4         112.00273             7727.29092        5296.97070
#
#   Road_Poor_above170 Road_NotReported_Percentage  Road_Good_Percentage  \
# 0          220.39271                       0.50%                80.18%
# 1          436.10563                      16.58%                36.94%
# 2          289.53975                       6.29%                59.54%
# 3          502.15671                       0.68%                56.71%
# 4         5005.21738                       0.55%                38.06%
#
#    Road_Fair_Percentage  Road_Poor_Percentage
# 0                14.52%                 2.64%
# 1                20.53%                17.90%
# 2                22.45%                 6.20%
# 3                27.61%                 7.76%
# 4                26.09%                24.65%
#
# [5 rows x 35 columns]

# %%
type(data_2018["Count_All"])
# Out:
# pandas.core.series.Series

# %%
bridge_state = []

# for i in range(0,1): # use for testing
for i in range(0,len(data_2018)):
    condition = [
        ["bridge_count_all", data_2018.iloc[i,3]],
        ["bridge_count_good", data_2018.iloc[i,4]],
        ["bridge_count_fair", data_2018.iloc[i,5]],
        ["bridge_count_poor", data_2018.iloc[i,6]],
        ["bridge_area_all", data_2018.iloc[i,7]],
        ["bridge_area_good", data_2018.iloc[i,8]],
        ["bridge_area_fair", data_2018.iloc[i,9]],
        ["bridge_area_poor", data_2018.iloc[i,10]],
        ["bridge_percentage_good", data_2018.iloc[i,11]],
        ["bridge_percentage_fair", data_2018.iloc[i,12]],
        ["bridge_percentage_poor", data_2018.iloc[i,13]],
        ["bridge_area_percent_good", data_2018.iloc[i,14]],
        ["bridge_area_percent_fair", data_2018.iloc[i,15]],
        ["bridge_area_percent_poor", data_2018.iloc[i,16]],
        ["total_tunnel_elements", data_2018.iloc[i,17]],
        ["tunnel_condition_good", data_2018.iloc[i,18]],
        ["tunnel_condition_fair", data_2018.iloc[i,19]],
        ["tunnel_condition_poor", data_2018.iloc[i,20]],
        ["tunnel_condition_severe", data_2018.iloc[i,21]],
        ["condition_percentage_good", data_2018.iloc[i,22]],
        ["condition_percentage_fair", data_2018.iloc[i,23]],
        ["condition_percentage_poor", data_2018.iloc[i,24]],
        ["condition_percentage_severe", data_2018.iloc[i,25]],
        ["road_total", data_2018.iloc[i,26]],
        ["not_reported_road", data_2018.iloc[i,27]],
        ["road_good", data_2018.iloc[i,28]],
        ["road_fair", data_2018.iloc[i,29]],
        ["road_poor", data_2018.iloc[i,30]],
        ["not_reported_road_percent", data_2018.iloc[i,31]],
        ["road_good_percent", data_2018.iloc[i,32]],
        ["road_fair_percent", data_2018.iloc[i,33]],
        ["road_poor_percent", data_2018.iloc[i,34]]
    ]
#     if i == 0:
#         bridge_state = [condition]
#     else:
    bridge_state.append(condition)

# %%
len(bridge_state)
# Out:
# 52

# %%
bridge_state
# Out:
# [[['bridge_count_all', 16130],
#   ['bridge_count_good', 6838],
#   ['bridge_count_fair', 8603],
#   ['bridge_count_poor', 689],
#   ['bridge_area_all', 9760735],
#   ['bridge_area_good', 3661978],
#   ['bridge_area_fair', 5851785],
#   ['bridge_area_poor', 246971],
#   ['bridge_percentage_good', '42.39%'],
#   ['bridge_percentage_fair', '53.34%'],
#   ['bridge_percentage_poor', '4.27%'],
#   ['bridge_area_percent_good', '37.52%'],
#   ['bridge_area_percent_fair', '59.95%'],
#   ['bridge_area_percent_poor', '2.53%'],
#   ['total_tunnel_elements', 1998282],
#   ['tunnel_condition_good', 1725296],
#   ['tunnel_condition_fair', 251583],
#   ['tunnel_condition_poor', 21191],
#   ['tunnel_condition_severe', 212],
#   ['condition_percentage_good', '86.34%'],
#   ['condition_percentage_fair', '12.59%'],
#   ['condition_percentage_poor', '1.06%'],
#   ['condition_percentage_severe', '0.01%'],
#   ['road_total', 8345.55725],
#   ['not_reported_road', 42.07674],
#   ['road_good', 6691.66651],
#   ['road_fair', 1211.777],
#   ['road_poor', 220.39271000000002],
#   ['not_reported_road_percent', '0.50%'],
#   ['road_good_percent', '80.18%'],
#   ['road_fair_percent', '14.52%'],
#   ['road_poor_percent', '2.64%']],
#  [['bridge_count_all', 1592],
#   ['bridge_count_good', 711],
#   ['bridge_count_fair', 725],
#   ['bridge_count_poor', 155],
#   ['bridge_area_all', 743788],
#   ['bridge_area_good', 298515],
#   ['bridge_area_fair', 385915],
#   ['bridge_area_poor', 59158],
#   ['bridge_percentage_good', '44.66%'],
#   ['bridge_percentage_fair', '45.54%'],
#   ['bridge_percentage_poor', '9.74%'],
#   ['bridge_area_percent_good', '40.13%'],
#   ['bridge_area_percent_fair', '51.89%'],
#   ['bridge_area_percent_poor', '7.95%'],
#   ['total_tunnel_elements', 1098774],
#   ['tunnel_condition_good', 353522],
#   ['tunnel_condition_fair', 511542],
#   ['tunnel_condition_poor', 188371],
#   ['tunnel_condition_severe', 45339],
#   ['condition_percentage_good', '32.17%'],
#   ['condition_percentage_fair', '46.56%'],
#   ['condition_percentage_poor', '17.14%'],
#   ['condition_percentage_severe', '4.13%'],
#   ['road_total', 2436.94823],
#   ['not_reported_road', 404.07334],
#   ['road_good', 900.09878],
#   ['road_fair', 500.26404],
#   ['road_poor', 436.10562999999996],
#   ['not_reported_road_percent', '16.58%'],
#   ['road_good_percent', '36.94%'],
#   ['road_fair_percent', '20.53%'],
#   ['road_poor_percent', '17.90%']],
#  [['bridge_count_all', 8294],
#   ['bridge_count_good', 5068],
#   ['bridge_count_fair', 3076],
#   ['bridge_count_poor', 150],
#   ['bridge_area_all', 5846176],
#   ['bridge_area_good', 3169212],
#   ['bridge_area_fair', 2581507],
#   ['bridge_area_poor', 95457],
#   ['bridge_percentage_good', '61.10%'],
#   ['bridge_percentage_fair', '37.09%'],
#   ['bridge_percentage_poor', '1.81%'],
#   ['bridge_area_percent_good', '54.21%'],
#   ['bridge_area_percent_fair', '44.16%'],
#   ['bridge_area_percent_poor', '1.63%'],
#   ['total_tunnel_elements', 1750631],
#   ['tunnel_condition_good', 1554508],
#   ['tunnel_condition_fair', 164065],
#   ['tunnel_condition_poor', 28904],
#   ['tunnel_condition_severe', 3154],
#   ['condition_percentage_good', '88.80%'],
#   ['condition_percentage_fair', '9.37%'],
#   ['condition_percentage_poor', '1.65%'],
#   ['condition_percentage_severe', '0.18%'],
#   ['road_total', 4668.3958],
#   ['not_reported_road', 293.60551],
#   ['road_good', 2779.42131],
#   ['road_fair', 1047.86457],
#   ['road_poor', 289.53975],
#   ['not_reported_road_percent', '6.29%'],
#   ['road_good_percent', '59.54%'],
#   ['road_fair_percent', '22.45%'],
#   ['road_poor_percent', '6.20%']],
#  [['bridge_count_all', 12892],
#   ['bridge_count_good', 6816],
#   ['bridge_count_fair', 5488],
#   ['bridge_count_poor', 588],
#   ['bridge_area_all', 6708589],
#   ['bridge_area_good', 3475609],
#   ['bridge_area_fair', 2919170],
#   ['bridge_area_poor', 313811],
#   ['bridge_percentage_good', '52.87%'],
#   ['bridge_percentage_fair', '42.57%'],
#   ['bridge_percentage_poor', '4.56%'],
#   ['bridge_area_percent_good', '51.81%'],
#   ['bridge_area_percent_fair', '43.51%'],
#   ['bridge_area_percent_poor', '4.68%'],
#   ['total_tunnel_elements', 376491],
#   ['tunnel_condition_good', 366899],
#   ['tunnel_condition_fair', 9322],
#   ['tunnel_condition_poor', 269],
#   ['tunnel_condition_severe', 1],
#   ['condition_percentage_good', '97.45%'],
#   ['condition_percentage_fair', '2.48%'],
#   ['condition_percentage_poor', '0.07%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 6472.53981],
#   ['not_reported_road', 43.913340000000005],
#   ['road_good', 3670.73899],
#   ['road_fair', 1787.2938100000001],
#   ['road_poor', 502.15671],
#   ['not_reported_road_percent', '0.68%'],
#   ['road_good_percent', '56.71%'],
#   ['road_fair_percent', '27.61%'],
#   ['road_poor_percent', '7.76%']],
#  [['bridge_count_all', 25737],
#   ['bridge_count_good', 14779],
#   ['bridge_count_fair', 9146],
#   ['bridge_count_poor', 1812],
#   ['bridge_area_all', 30067631],
#   ['bridge_area_good', 17623112],
#   ['bridge_area_fair', 10442456],
#   ['bridge_area_poor', 2002063],
#   ['bridge_percentage_good', '57.42%'],
#   ['bridge_percentage_fair', '35.54%'],
#   ['bridge_percentage_poor', '7.04%'],
#   ['bridge_area_percent_good', '58.61%'],
#   ['bridge_area_percent_fair', '34.73%'],
#   ['bridge_area_percent_poor', '6.66%'],
#   ['total_tunnel_elements', 16724871],
#   ['tunnel_condition_good', 15872091],
#   ['tunnel_condition_fair', 309136],
#   ['tunnel_condition_poor', 321655],
#   ['tunnel_condition_severe', 221989],
#   ['condition_percentage_good', '94.90%'],
#   ['condition_percentage_fair', '1.85%'],
#   ['condition_percentage_poor', '1.92%'],
#   ['condition_percentage_severe', '1.33%'],
#   ['road_total', 20302.043690000002],
#   ['not_reported_road', 112.00273],
#   ['road_good', 7727.29092],
#   ['road_fair', 5296.9707],
#   ['road_poor', 5005.21738],
#   ['not_reported_road_percent', '0.55%'],
#   ['road_good_percent', '38.06%'],
#   ['road_fair_percent', '26.09%'],
#   ['road_poor_percent', '24.65%']],
#  [['bridge_count_all', 8786],
#   ['bridge_count_good', 3694],
#   ['bridge_count_fair', 4618],
#   ['bridge_count_poor', 473],
#   ['bridge_area_all', 5024622],
#   ['bridge_area_good', 2359789],
#   ['bridge_area_fair', 2457413],
#   ['bridge_area_poor', 207344],
#   ['bridge_percentage_good', '42.04%'],
#   ['bridge_percentage_fair', '52.56%'],
#   ['bridge_percentage_poor', '5.38%'],
#   ['bridge_area_percent_good', '46.96%'],
#   ['bridge_area_percent_fair', '48.91%'],
#   ['bridge_area_percent_poor', '4.13%'],
#   ['total_tunnel_elements', 8393243],
#   ['tunnel_condition_good', 7399138],
#   ['tunnel_condition_fair', 513824],
#   ['tunnel_condition_poor', 463503],
#   ['tunnel_condition_severe', 16778],
#   ['condition_percentage_good', '88.16%'],
#   ['condition_percentage_fair', '6.12%'],
#   ['condition_percentage_poor', '5.52%'],
#   ['condition_percentage_severe', '0.20%'],
#   ['road_total', 8416.97253],
#   ['not_reported_road', 292.14165],
#   ['road_good', 3966.38527],
#   ['road_fair', 2596.11607],
#   ['road_poor', 937.00781],
#   ['not_reported_road_percent', '3.47%'],
#   ['road_good_percent', '47.12%'],
#   ['road_fair_percent', '30.84%'],
#   ['road_poor_percent', '11.13%']],
#  [['bridge_count_all', 4270],
#   ['bridge_count_good', 1238],
#   ['bridge_count_fair', 2724],
#   ['bridge_count_poor', 308],
#   ['bridge_area_all', 3414833],
#   ['bridge_area_good', 600502],
#   ['bridge_area_fair', 2406635],
#   ['bridge_area_poor', 407696],
#   ['bridge_percentage_good', '28.99%'],
#   ['bridge_percentage_fair', '63.79%'],
#   ['bridge_percentage_poor', '7.21%'],
#   ['bridge_area_percent_good', '17.59%'],
#   ['bridge_area_percent_fair', '70.48%'],
#   ['bridge_area_percent_poor', '11.94%'],
#   ['total_tunnel_elements', 847174],
#   ['tunnel_condition_good', 798660],
#   ['tunnel_condition_fair', 26306],
#   ['tunnel_condition_poor', 21969],
#   ['tunnel_condition_severe', 239],
#   ['condition_percentage_good', '94.27%'],
#   ['condition_percentage_fair', '3.11%'],
#   ['condition_percentage_poor', '2.59%'],
#   ['condition_percentage_severe', '0.03%'],
#   ['road_total', 1677.32807],
#   ['not_reported_road', 0.27171999999999996],
#   ['road_good', 776.03407],
#   ['road_fair', 520.82493],
#   ['road_poor', 234.8263],
#   ['not_reported_road_percent', '0.02%'],
#   ['road_good_percent', '46.27%'],
#   ['road_fair_percent', '31.05%'],
#   ['road_poor_percent', '14.00%']],
#  [['bridge_count_all', 863],
#   ['bridge_count_good', 195],
#   ['bridge_count_fair', 634],
#   ['bridge_count_poor', 34],
#   ['bridge_area_all', 1000357],
#   ['bridge_area_good', 141858],
#   ['bridge_area_fair', 800016],
#   ['bridge_area_poor', 58483],
#   ['bridge_percentage_good', '22.60%'],
#   ['bridge_percentage_fair', '73.46%'],
#   ['bridge_percentage_poor', '3.94%'],
#   ['bridge_area_percent_good', '14.18%'],
#   ['bridge_area_percent_fair', '79.97%'],
#   ['bridge_area_percent_poor', '5.85%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 500.87859000000003],
#   ['not_reported_road', 3.5568699999999995],
#   ['road_good', 314.43428],
#   ['road_fair', 122.10803999999999],
#   ['road_poor', 39.56467],
#   ['not_reported_road_percent', '0.71%'],
#   ['road_good_percent', '62.78%'],
#   ['road_fair_percent', '24.38%'],
#   ['road_poor_percent', '7.90%']],
#  [['bridge_count_all', 244],
#   ['bridge_count_good', 62],
#   ['bridge_count_fair', 174],
#   ['bridge_count_poor', 8],
#   ['bridge_area_all', 569296],
#   ['bridge_area_good', 75891],
#   ['bridge_area_fair', 470820],
#   ['bridge_area_poor', 22586],
#   ['bridge_percentage_good', '25.41%'],
#   ['bridge_percentage_fair', '71.31%'],
#   ['bridge_percentage_poor', '3.28%'],
#   ['bridge_area_percent_good', '13.33%'],
#   ['bridge_area_percent_fair', '82.70%'],
#   ['bridge_area_percent_poor', '3.97%'],
#   ['total_tunnel_elements', 2080205],
#   ['tunnel_condition_good', 1881520],
#   ['tunnel_condition_fair', 188719],
#   ['tunnel_condition_poor', 8879],
#   ['tunnel_condition_severe', 1087],
#   ['condition_percentage_good', '90.45%'],
#   ['condition_percentage_fair', '9.07%'],
#   ['condition_percentage_poor', '0.43%'],
#   ['condition_percentage_severe', '0.05%'],
#   ['road_total', 133.861],
#   ['not_reported_road', 0.125],
#   ['road_good', 3.406],
#   ['road_fair', 18.832],
#   ['road_poor', 111.365],
#   ['not_reported_road_percent', '0.09%'],
#   ['road_good_percent', '2.54%'],
#   ['road_fair_percent', '14.07%'],
#   ['road_poor_percent', '83.19%']],
#  [['bridge_count_all', 12435],
#   ['bridge_count_good', 8389],
#   ['bridge_count_fair', 3717],
#   ['bridge_count_poor', 328],
#   ['bridge_area_all', 17516213],
#   ['bridge_area_good', 11658699],
#   ['bridge_area_fair', 5575956],
#   ['bridge_area_poor', 280394],
#   ['bridge_percentage_good', '67.46%'],
#   ['bridge_percentage_fair', '29.89%'],
#   ['bridge_percentage_poor', '2.64%'],
#   ['bridge_area_percent_good', '66.56%'],
#   ['bridge_area_percent_fair', '31.83%'],
#   ['bridge_area_percent_poor', '1.60%'],
#   ['total_tunnel_elements', 2877174],
#   ['tunnel_condition_good', 2872013],
#   ['tunnel_condition_fair', 4442],
#   ['tunnel_condition_poor', 596],
#   ['tunnel_condition_severe', 123],
#   ['condition_percentage_good', '99.82%'],
#   ['condition_percentage_fair', '0.15%'],
#   ['condition_percentage_poor', '0.02%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 11021.73667],
#   ['not_reported_road', 17.56798],
#   ['road_good', 8531.2851],
#   ['road_fair', 1872.60256],
#   ['road_poor', 320.18109],
#   ['not_reported_road_percent', '0.16%'],
#   ['road_good_percent', '77.40%'],
#   ['road_fair_percent', '16.99%'],
#   ['road_poor_percent', '2.90%']],
#  [['bridge_count_all', 14879],
#   ['bridge_count_good', 6303],
#   ['bridge_count_fair', 8082],
#   ['bridge_count_poor', 494],
#   ['bridge_area_all', 10082064],
#   ['bridge_area_good', 4640184],
#   ['bridge_area_fair', 5205927],
#   ['bridge_area_poor', 235953],
#   ['bridge_percentage_good', '42.36%'],
#   ['bridge_percentage_fair', '54.32%'],
#   ['bridge_percentage_poor', '3.32%'],
#   ['bridge_area_percent_good', '46.02%'],
#   ['bridge_area_percent_fair', '51.64%'],
#   ['bridge_area_percent_poor', '2.34%'],
#   ['total_tunnel_elements', 353991],
#   ['tunnel_condition_good', 338613],
#   ['tunnel_condition_fair', 12364],
#   ['tunnel_condition_poor', 2997],
#   ['tunnel_condition_severe', 17],
#   ['condition_percentage_good', '95.66%'],
#   ['condition_percentage_fair', '3.49%'],
#   ['condition_percentage_poor', '0.85%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 12190.23568],
#   ['not_reported_road', 1650.0442],
#   ['road_good', 8143.707329999999],
#   ['road_fair', 1841.1304],
#   ['road_poor', 284.34236],
#   ['not_reported_road_percent', '13.54%'],
#   ['road_good_percent', '66.81%'],
#   ['road_fair_percent', '15.10%'],
#   ['road_poor_percent', '2.33%']],
#  [['bridge_count_all', 1137],
#   ['bridge_count_good', 355],
#   ['bridge_count_fair', 704],
#   ['bridge_count_poor', 78],
#   ['bridge_area_all', 1324180],
#   ['bridge_area_good', 326663],
#   ['bridge_area_fair', 968926],
#   ['bridge_area_poor', 28592],
#   ['bridge_percentage_good', '31.22%'],
#   ['bridge_percentage_fair', '61.92%'],
#   ['bridge_percentage_poor', '6.86%'],
#   ['bridge_area_percent_good', '24.67%'],
#   ['bridge_area_percent_fair', '73.17%'],
#   ['bridge_area_percent_poor', '2.16%'],
#   ['total_tunnel_elements', 2850196],
#   ['tunnel_condition_good', 2477234],
#   ['tunnel_condition_fair', 144961],
#   ['tunnel_condition_poor', 227997],
#   ['tunnel_condition_severe', 4],
#   ['condition_percentage_good', '86.91%'],
#   ['condition_percentage_fair', '5.09%'],
#   ['condition_percentage_poor', '8.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 691.67],
#   ['not_reported_road', 1.42],
#   ['road_good', 195.169],
#   ['road_fair', 226.359],
#   ['road_poor', 167.59799999999998],
#   ['not_reported_road_percent', '0.21%'],
#   ['road_good_percent', '28.22%'],
#   ['road_fair_percent', '32.73%'],
#   ['road_poor_percent', '24.23%']],
#  [['bridge_count_all', 4482],
#   ['bridge_count_good', 1259],
#   ['bridge_count_fair', 2907],
#   ['bridge_count_poor', 315],
#   ['bridge_area_all', 1756871],
#   ['bridge_area_good', 442282],
#   ['bridge_area_fair', 1229647],
#   ['bridge_area_poor', 84873],
#   ['bridge_percentage_good', '28.09%'],
#   ['bridge_percentage_fair', '64.86%'],
#   ['bridge_percentage_poor', '7.03%'],
#   ['bridge_area_percent_good', '25.17%'],
#   ['bridge_area_percent_fair', '69.99%'],
#   ['bridge_area_percent_poor', '4.83%'],
#   ['total_tunnel_elements', 377722],
#   ['tunnel_condition_good', 205950],
#   ['tunnel_condition_fair', 50612],
#   ['tunnel_condition_poor', 108733],
#   ['tunnel_condition_severe', 12427],
#   ['condition_percentage_good', '54.52%'],
#   ['condition_percentage_fair', '13.40%'],
#   ['condition_percentage_poor', '28.79%'],
#   ['condition_percentage_severe', '3.29%'],
#   ['road_total', 3967.99987],
#   ['not_reported_road', 340.78243],
#   ['road_good', 2654.56765],
#   ['road_fair', 723.41148],
#   ['road_poor', 111.87102],
#   ['not_reported_road_percent', '8.59%'],
#   ['road_good_percent', '66.90%'],
#   ['road_fair_percent', '18.23%'],
#   ['road_poor_percent', '2.82%']],
#  [['bridge_count_all', 26809],
#   ['bridge_count_good', 13438],
#   ['bridge_count_fair', 11098],
#   ['bridge_count_poor', 2273],
#   ['bridge_area_all', 13524885],
#   ['bridge_area_good', 5027056],
#   ['bridge_area_fair', 6999849],
#   ['bridge_area_poor', 1497979],
#   ['bridge_percentage_good', '50.12%'],
#   ['bridge_percentage_fair', '41.40%'],
#   ['bridge_percentage_poor', '8.48%'],
#   ['bridge_area_percent_good', '37.17%'],
#   ['bridge_area_percent_fair', '51.76%'],
#   ['bridge_area_percent_poor', '11.08%'],
#   ['total_tunnel_elements', 716184],
#   ['tunnel_condition_good', 580246],
#   ['tunnel_condition_fair', 135014],
#   ['tunnel_condition_poor', 924],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '81.02%'],
#   ['condition_percentage_fair', '18.85%'],
#   ['condition_percentage_poor', '0.13%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 12318.03017],
#   ['not_reported_road', 25.42],
#   ['road_good', 6742.789940000001],
#   ['road_fair', 3555.5932799999996],
#   ['road_poor', 1130.7175300000001],
#   ['not_reported_road_percent', '0.21%'],
#   ['road_good_percent', '54.74%'],
#   ['road_fair_percent', '28.86%'],
#   ['road_poor_percent', '9.18%']],
#  [['bridge_count_all', 19280],
#   ['bridge_count_good', 7959],
#   ['bridge_count_fair', 10114],
#   ['bridge_count_poor', 1203],
#   ['bridge_area_all', 8197646],
#   ['bridge_area_good', 3735606],
#   ['bridge_area_fair', 4134643],
#   ['bridge_area_poor', 325675],
#   ['bridge_percentage_good', '41.28%'],
#   ['bridge_percentage_fair', '52.46%'],
#   ['bridge_percentage_poor', '6.24%'],
#   ['bridge_area_percent_good', '45.57%'],
#   ['bridge_area_percent_fair', '50.44%'],
#   ['bridge_area_percent_poor', '3.97%'],
#   ['total_tunnel_elements', 845234],
#   ['tunnel_condition_good', 756899],
#   ['tunnel_condition_fair', 56743],
#   ['tunnel_condition_poor', 28362],
#   ['tunnel_condition_severe', 3230],
#   ['condition_percentage_good', '89.55%'],
#   ['condition_percentage_fair', '6.71%'],
#   ['condition_percentage_poor', '3.36%'],
#   ['condition_percentage_severe', '0.38%'],
#   ['road_total', 7427.2889700000005],
#   ['not_reported_road', 699.9549],
#   ['road_good', 4483.88898],
#   ['road_fair', 1529.8601099999998],
#   ['road_poor', 397.29233999999997],
#   ['not_reported_road_percent', '9.42%'],
#   ['road_good_percent', '60.37%'],
#   ['road_fair_percent', '20.60%'],
#   ['road_poor_percent', '5.35%']],
#  [['bridge_count_all', 24123],
#   ['bridge_count_good', 9180],
#   ['bridge_count_fair', 10263],
#   ['bridge_count_poor', 4675],
#   ['bridge_area_all', 8806907],
#   ['bridge_area_good', 4044915],
#   ['bridge_area_fair', 3872593],
#   ['bridge_area_poor', 888963],
#   ['bridge_percentage_good', '38.05%'],
#   ['bridge_percentage_fair', '42.54%'],
#   ['bridge_percentage_poor', '19.38%'],
#   ['bridge_area_percent_good', '45.93%'],
#   ['bridge_area_percent_fair', '43.97%'],
#   ['bridge_area_percent_poor', '10.09%'],
#   ['total_tunnel_elements', 11754],
#   ['tunnel_condition_good', 10999],
#   ['tunnel_condition_fair', 535],
#   ['tunnel_condition_poor', 220],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '93.58%'],
#   ['condition_percentage_fair', '4.55%'],
#   ['condition_percentage_poor', '1.87%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 5125.28376],
#   ['not_reported_road', 95.36876],
#   ['road_good', 2952.502],
#   ['road_fair', 1307.4769999999999],
#   ['road_poor', 470.995],
#   ['not_reported_road_percent', '1.86%'],
#   ['road_good_percent', '57.61%'],
#   ['road_fair_percent', '25.51%'],
#   ['road_poor_percent', '9.19%']],
#  [['bridge_count_all', 24906],
#   ['bridge_count_good', 13594],
#   ['bridge_count_fair', 10024],
#   ['bridge_count_poor', 1288],
#   ['bridge_area_all', 8680998],
#   ['bridge_area_good', 5693563],
#   ['bridge_area_fair', 2743165],
#   ['bridge_area_poor', 244271],
#   ['bridge_percentage_good', '54.58%'],
#   ['bridge_percentage_fair', '40.25%'],
#   ['bridge_percentage_poor', '5.17%'],
#   ['bridge_area_percent_good', '65.59%'],
#   ['bridge_area_percent_fair', '31.60%'],
#   ['bridge_area_percent_poor', '2.81%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 8673.254570000001],
#   ['not_reported_road', 36.70533],
#   ['road_good', 7011.34885],
#   ['road_fair', 1275.14805],
#   ['road_poor', 177.65511],
#   ['not_reported_road_percent', '0.42%'],
#   ['road_good_percent', '80.84%'],
#   ['road_fair_percent', '14.70%'],
#   ['road_poor_percent', '2.05%']],
#  [['bridge_count_all', 14368],
#   ['bridge_count_good', 5239],
#   ['bridge_count_fair', 8111],
#   ['bridge_count_poor', 1016],
#   ['bridge_area_all', 6509802],
#   ['bridge_area_good', 2480985],
#   ['bridge_area_fair', 3717280],
#   ['bridge_area_poor', 310678],
#   ['bridge_percentage_good', '36.46%'],
#   ['bridge_percentage_fair', '56.45%'],
#   ['bridge_percentage_poor', '7.07%'],
#   ['bridge_area_percent_good', '38.11%'],
#   ['bridge_area_percent_fair', '57.10%'],
#   ['bridge_area_percent_poor', '4.77%'],
#   ['total_tunnel_elements', 1830111],
#   ['tunnel_condition_good', 1632734],
#   ['tunnel_condition_fair', 172369],
#   ['tunnel_condition_poor', 24583],
#   ['tunnel_condition_severe', 425],
#   ['condition_percentage_good', '89.22%'],
#   ['condition_percentage_fair', '9.42%'],
#   ['condition_percentage_poor', '1.34%'],
#   ['condition_percentage_severe', '0.02%'],
#   ['road_total', 5605.2110299999995],
#   ['not_reported_road', 64.99903],
#   ['road_good', 3847.0002600000003],
#   ['road_fair', 1290.76068],
#   ['road_poor', 207.06101],
#   ['not_reported_road_percent', '1.16%'],
#   ['road_good_percent', '68.63%'],
#   ['road_fair_percent', '23.03%'],
#   ['road_poor_percent', '3.69%']],
#  [['bridge_count_all', 12899],
#   ['bridge_count_good', 6484],
#   ['bridge_count_fair', 4733],
#   ['bridge_count_poor', 1678],
#   ['bridge_area_all', 16587147],
#   ['bridge_area_good', 7752468],
#   ['bridge_area_fair', 7449875],
#   ['bridge_area_poor', 1384201],
#   ['bridge_percentage_good', '50.27%'],
#   ['bridge_percentage_fair', '36.69%'],
#   ['bridge_percentage_poor', '13.01%'],
#   ['bridge_area_percent_good', '46.74%'],
#   ['bridge_area_percent_fair', '44.91%'],
#   ['bridge_area_percent_poor', '8.35%'],
#   ['total_tunnel_elements', 867135],
#   ['tunnel_condition_good', 695170],
#   ['tunnel_condition_fair', 154903],
#   ['tunnel_condition_poor', 15968],
#   ['tunnel_condition_severe', 1094],
#   ['condition_percentage_good', '80.17%'],
#   ['condition_percentage_fair', '17.86%'],
#   ['condition_percentage_poor', '1.84%'],
#   ['condition_percentage_severe', '0.13%'],
#   ['road_total', 5037.27786],
#   ['not_reported_road', 161.20703999999998],
#   ['road_good', 2271.19515],
#   ['road_fair', 1481.47304],
#   ['road_poor', 692.4304400000001],
#   ['not_reported_road_percent', '3.20%'],
#   ['road_good_percent', '45.09%'],
#   ['road_fair_percent', '29.41%'],
#   ['road_poor_percent', '13.75%']],
#  [['bridge_count_all', 2473],
#   ['bridge_count_good', 786],
#   ['bridge_count_fair', 1362],
#   ['bridge_count_poor', 325],
#   ['bridge_area_all', 1264519],
#   ['bridge_area_good', 451266],
#   ['bridge_area_fair', 708474],
#   ['bridge_area_poor', 104779],
#   ['bridge_percentage_good', '31.78%'],
#   ['bridge_percentage_fair', '55.07%'],
#   ['bridge_percentage_poor', '13.14%'],
#   ['bridge_area_percent_good', '35.69%'],
#   ['bridge_area_percent_fair', '56.03%'],
#   ['bridge_area_percent_poor', '8.29%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 2253.808],
#   ['not_reported_road', 5.461],
#   ['road_good', 1365.0970000000002],
#   ['road_fair', 498.7],
#   ['road_poor', 254.67],
#   ['not_reported_road_percent', '0.24%'],
#   ['road_good_percent', '60.57%'],
#   ['road_fair_percent', '22.13%'],
#   ['road_poor_percent', '11.30%']],
#  [['bridge_count_all', 5357],
#   ['bridge_count_good', 1757],
#   ['bridge_count_fair', 3326],
#   ['bridge_count_poor', 274],
#   ['bridge_area_all', 5426511],
#   ['bridge_area_good', 1602956],
#   ['bridge_area_fair', 3648777],
#   ['bridge_area_poor', 174778],
#   ['bridge_percentage_good', '32.80%'],
#   ['bridge_percentage_fair', '62.09%'],
#   ['bridge_percentage_poor', '5.11%'],
#   ['bridge_area_percent_good', '29.54%'],
#   ['bridge_area_percent_fair', '67.24%'],
#   ['bridge_area_percent_poor', '3.22%'],
#   ['total_tunnel_elements', 9210642],
#   ['tunnel_condition_good', 8534504],
#   ['tunnel_condition_fair', 629737],
#   ['tunnel_condition_poor', 36737],
#   ['tunnel_condition_severe', 9664],
#   ['condition_percentage_good', '92.66%'],
#   ['condition_percentage_fair', '6.84%'],
#   ['condition_percentage_poor', '0.40%'],
#   ['condition_percentage_severe', '0.10%'],
#   ['road_total', 2920.0517600000003],
#   ['not_reported_road', 26.803340000000002],
#   ['road_good', 1871.6583100000003],
#   ['road_fair', 544.90628],
#   ['road_poor', 345.37242000000003],
#   ['not_reported_road_percent', '0.92%'],
#   ['road_good_percent', '64.10%'],
#   ['road_fair_percent', '18.66%'],
#   ['road_poor_percent', '11.83%']],
#  [['bridge_count_all', 5215],
#   ['bridge_count_good', 1370],
#   ['bridge_count_fair', 3364],
#   ['bridge_count_poor', 481],
#   ['bridge_area_all', 4119863],
#   ['bridge_area_good', 869419],
#   ['bridge_area_fair', 2766279],
#   ['bridge_area_poor', 484164],
#   ['bridge_percentage_good', '26.27%'],
#   ['bridge_percentage_fair', '64.51%'],
#   ['bridge_percentage_poor', '9.22%'],
#   ['bridge_area_percent_good', '21.10%'],
#   ['bridge_area_percent_fair', '67.14%'],
#   ['bridge_area_percent_poor', '11.75%'],
#   ['total_tunnel_elements', 21869922],
#   ['tunnel_condition_good', 20794668],
#   ['tunnel_condition_fair', 789875],
#   ['tunnel_condition_poor', 250255],
#   ['tunnel_condition_severe', 35124],
#   ['condition_percentage_good', '95.08%'],
#   ['condition_percentage_fair', '3.61%'],
#   ['condition_percentage_poor', '1.14%'],
#   ['condition_percentage_severe', '0.16%'],
#   ['road_total', 3292.65681],
#   ['not_reported_road', 30.89643],
#   ['road_good', 1284.03238],
#   ['road_fair', 744.62215],
#   ['road_poor', 899.9518199999999],
#   ['not_reported_road_percent', '0.94%'],
#   ['road_good_percent', '39.00%'],
#   ['road_fair_percent', '22.61%'],
#   ['road_poor_percent', '27.33%']],
#  [['bridge_count_all', 11228],
#   ['bridge_count_good', 4479],
#   ['bridge_count_fair', 5548],
#   ['bridge_count_poor', 1196],
#   ['bridge_area_all', 6445678],
#   ['bridge_area_good', 2281475],
#   ['bridge_area_fair', 3564054],
#   ['bridge_area_poor', 599552],
#   ['bridge_percentage_good', '39.89%'],
#   ['bridge_percentage_fair', '49.41%'],
#   ['bridge_percentage_poor', '10.65%'],
#   ['bridge_area_percent_good', '35.40%'],
#   ['bridge_area_percent_fair', '55.29%'],
#   ['bridge_area_percent_poor', '9.30%'],
#   ['total_tunnel_elements', 3821360],
#   ['tunnel_condition_good', 3351279],
#   ['tunnel_condition_fair', 303290],
#   ['tunnel_condition_poor', 28488],
#   ['tunnel_condition_severe', 138303],
#   ['condition_percentage_good', '87.70%'],
#   ['condition_percentage_fair', '7.94%'],
#   ['condition_percentage_poor', '0.75%'],
#   ['condition_percentage_severe', '3.62%'],
#   ['road_total', 11322.30921],
#   ['not_reported_road', 62.13961],
#   ['road_good', 7180.33345],
#   ['road_fair', 2405.39142],
#   ['road_poor', 1104.1308800000002],
#   ['not_reported_road_percent', '0.55%'],
#   ['road_good_percent', '63.42%'],
#   ['road_fair_percent', '21.24%'],
#   ['road_poor_percent', '9.75%']],
#  [['bridge_count_all', 13358],
#   ['bridge_count_good', 8259],
#   ['bridge_count_fair', 4431],
#   ['bridge_count_poor', 668],
#   ['bridge_area_all', 7132639],
#   ['bridge_area_good', 3859452],
#   ['bridge_area_fair', 3022860],
#   ['bridge_area_poor', 250327],
#   ['bridge_percentage_good', '61.83%'],
#   ['bridge_percentage_fair', '33.17%'],
#   ['bridge_percentage_poor', '5.00%'],
#   ['bridge_area_percent_good', '54.11%'],
#   ['bridge_area_percent_fair', '42.38%'],
#   ['bridge_area_percent_poor', '3.51%'],
#   ['total_tunnel_elements', 1618213],
#   ['tunnel_condition_good', 1558245],
#   ['tunnel_condition_fair', 56271],
#   ['tunnel_condition_poor', 3552],
#   ['tunnel_condition_severe', 145],
#   ['condition_percentage_good', '96.29%'],
#   ['condition_percentage_fair', '3.48%'],
#   ['condition_percentage_poor', '0.22%'],
#   ['condition_percentage_severe', '0.01%'],
#   ['road_total', 11692.47107],
#   ['not_reported_road', 18.53516],
#   ['road_good', 7211.29516],
#   ['road_fair', 2941.60217],
#   ['road_poor', 894.65814],
#   ['not_reported_road_percent', '0.16%'],
#   ['road_good_percent', '61.67%'],
#   ['road_fair_percent', '25.16%'],
#   ['road_poor_percent', '7.65%']],
#  [['bridge_count_all', 17071],
#   ['bridge_count_good', 10711],
#   ['bridge_count_fair', 4757],
#   ['bridge_count_poor', 1603],
#   ['bridge_area_all', 9940070],
#   ['bridge_area_good', 6504401],
#   ['bridge_area_fair', 3019248],
#   ['bridge_area_poor', 416420],
#   ['bridge_percentage_good', '62.74%'],
#   ['bridge_percentage_fair', '27.87%'],
#   ['bridge_percentage_poor', '9.39%'],
#   ['bridge_area_percent_good', '65.44%'],
#   ['bridge_area_percent_fair', '30.37%'],
#   ['bridge_area_percent_poor', '4.19%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 7416.30245],
#   ['not_reported_road', 35.00645],
#   ['road_good', 4268.69052],
#   ['road_fair', 1868.49773],
#   ['road_poor', 711.67987],
#   ['not_reported_road_percent', '0.47%'],
#   ['road_good_percent', '57.56%'],
#   ['road_fair_percent', '25.19%'],
#   ['road_poor_percent', '9.60%']],
#  [['bridge_count_all', 24512],
#   ['bridge_count_good', 10579],
#   ['bridge_count_fair', 11817],
#   ['bridge_count_poor', 2116],
#   ['bridge_area_all', 10701764],
#   ['bridge_area_good', 4325670],
#   ['bridge_area_fair', 5466291],
#   ['bridge_area_poor', 909803],
#   ['bridge_percentage_good', '43.16%'],
#   ['bridge_percentage_fair', '48.21%'],
#   ['bridge_percentage_poor', '8.63%'],
#   ['bridge_area_percent_good', '40.42%'],
#   ['bridge_area_percent_fair', '51.08%'],
#   ['bridge_area_percent_poor', '8.50%'],
#   ['total_tunnel_elements', 487244],
#   ['tunnel_condition_good', 477394],
#   ['tunnel_condition_fair', 7986],
#   ['tunnel_condition_poor', 1860],
#   ['tunnel_condition_severe', 4],
#   ['condition_percentage_good', '97.98%'],
#   ['condition_percentage_fair', '1.64%'],
#   ['condition_percentage_poor', '0.38%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 9769.67309],
#   ['not_reported_road', 32.58728],
#   ['road_good', 5974.73704],
#   ['road_fair', 2673.6734300000003],
#   ['road_poor', 550.9705],
#   ['not_reported_road_percent', '0.33%'],
#   ['road_good_percent', '61.16%'],
#   ['road_fair_percent', '27.37%'],
#   ['road_poor_percent', '5.64%']],
#  [['bridge_count_all', 5265],
#   ['bridge_count_good', 1605],
#   ['bridge_count_fair', 3270],
#   ['bridge_count_poor', 390],
#   ['bridge_area_all', 2084807],
#   ['bridge_area_good', 459891],
#   ['bridge_area_fair', 1463582],
#   ['bridge_area_poor', 161334],
#   ['bridge_percentage_good', '30.48%'],
#   ['bridge_percentage_fair', '62.11%'],
#   ['bridge_percentage_poor', '7.41%'],
#   ['bridge_area_percent_good', '22.06%'],
#   ['bridge_area_percent_fair', '70.20%'],
#   ['bridge_area_percent_poor', '7.74%'],
#   ['total_tunnel_elements', 122998],
#   ['tunnel_condition_good', 41881],
#   ['tunnel_condition_fair', 34368],
#   ['tunnel_condition_poor', 41177],
#   ['tunnel_condition_severe', 5572],
#   ['condition_percentage_good', '34.05%'],
#   ['condition_percentage_fair', '27.94%'],
#   ['condition_percentage_poor', '33.48%'],
#   ['condition_percentage_severe', '4.53%'],
#   ['road_total', 7081.572270000001],
#   ['not_reported_road', 11.891169999999999],
#   ['road_good', 4850.72435],
#   ['road_fair', 1595.85381],
#   ['road_poor', 345.73368],
#   ['not_reported_road_percent', '0.17%'],
#   ['road_good_percent', '68.50%'],
#   ['road_fair_percent', '22.54%'],
#   ['road_poor_percent', '4.88%']],
#  [['bridge_count_all', 15349],
#   ['bridge_count_good', 7985],
#   ['bridge_count_fair', 6003],
#   ['bridge_count_poor', 1358],
#   ['bridge_area_all', 4340537],
#   ['bridge_area_good', 2586969],
#   ['bridge_area_fair', 1528921],
#   ['bridge_area_poor', 224124],
#   ['bridge_percentage_good', '52.02%'],
#   ['bridge_percentage_fair', '39.11%'],
#   ['bridge_percentage_poor', '8.85%'],
#   ['bridge_area_percent_good', '59.60%'],
#   ['bridge_area_percent_fair', '35.22%'],
#   ['bridge_area_percent_poor', '5.16%'],
#   ['total_tunnel_elements', 48963],
#   ['tunnel_condition_good', 45393],
#   ['tunnel_condition_fair', 1201],
#   ['tunnel_condition_poor', 2369],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '92.71%'],
#   ['condition_percentage_fair', '2.45%'],
#   ['condition_percentage_poor', '4.84%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 7549.258959999999],
#   ['not_reported_road', 350.18852000000004],
#   ['road_good', 5479.010310000001],
#   ['road_fair', 1033.80483],
#   ['road_poor', 438.94634],
#   ['not_reported_road_percent', '4.64%'],
#   ['road_good_percent', '72.58%'],
#   ['road_fair_percent', '13.69%'],
#   ['road_poor_percent', '5.81%']],
#  [['bridge_count_all', 1979],
#   ['bridge_count_good', 978],
#   ['bridge_count_fair', 974],
#   ['bridge_count_poor', 27],
#   ['bridge_area_all', 1791492],
#   ['bridge_area_good', 838231],
#   ['bridge_area_fair', 939426],
#   ['bridge_area_poor', 13835],
#   ['bridge_percentage_good', '49.42%'],
#   ['bridge_percentage_fair', '49.22%'],
#   ['bridge_percentage_poor', '1.36%'],
#   ['bridge_area_percent_good', '46.79%'],
#   ['bridge_area_percent_fair', '52.44%'],
#   ['bridge_area_percent_poor', '0.77%'],
#   ['total_tunnel_elements', 1445150],
#   ['tunnel_condition_good', 1322764],
#   ['tunnel_condition_fair', 71870],
#   ['tunnel_condition_poor', 50104],
#   ['tunnel_condition_severe', 412],
#   ['condition_percentage_good', '91.53%'],
#   ['condition_percentage_fair', '4.97%'],
#   ['condition_percentage_poor', '3.47%'],
#   ['condition_percentage_severe', '0.03%'],
#   ['road_total', 3291.20628],
#   ['not_reported_road', 28.203940000000003],
#   ['road_good', 2707.8088199999997],
#   ['road_fair', 426.50521],
#   ['road_poor', 63.94607],
#   ['not_reported_road_percent', '0.86%'],
#   ['road_good_percent', '82.27%'],
#   ['road_fair_percent', '12.96%'],
#   ['road_poor_percent', '1.94%']],
#  [['bridge_count_all', 2494],
#   ['bridge_count_good', 1323],
#   ['bridge_count_fair', 947],
#   ['bridge_count_poor', 224],
#   ['bridge_area_all', 1130225],
#   ['bridge_area_good', 631927],
#   ['bridge_area_fair', 404980],
#   ['bridge_area_poor', 93318],
#   ['bridge_percentage_good', '53.05%'],
#   ['bridge_percentage_fair', '37.97%'],
#   ['bridge_percentage_poor', '8.98%'],
#   ['bridge_area_percent_good', '55.91%'],
#   ['bridge_area_percent_fair', '35.83%'],
#   ['bridge_area_percent_poor', '8.26%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 1482.88402],
#   ['not_reported_road', 3.7777199999999995],
#   ['road_good', 1043.83596],
#   ['road_fair', 195.63154],
#   ['road_poor', 183.21678],
#   ['not_reported_road_percent', '0.25%'],
#   ['road_good_percent', '70.39%'],
#   ['road_fair_percent', '13.19%'],
#   ['road_poor_percent', '12.36%']],
#  [['bridge_count_all', 6746],
#   ['bridge_count_good', 1819],
#   ['bridge_count_fair', 4383],
#   ['bridge_count_poor', 544],
#   ['bridge_area_all', 7002430],
#   ['bridge_area_good', 1654510],
#   ['bridge_area_fair', 4852975],
#   ['bridge_area_poor', 494945],
#   ['bridge_percentage_good', '26.96%'],
#   ['bridge_percentage_fair', '64.97%'],
#   ['bridge_percentage_poor', '8.06%'],
#   ['bridge_area_percent_good', '23.63%'],
#   ['bridge_area_percent_fair', '69.30%'],
#   ['bridge_area_percent_poor', '7.07%'],
#   ['total_tunnel_elements', 8281076],
#   ['tunnel_condition_good', 7926636],
#   ['tunnel_condition_fair', 226542],
#   ['tunnel_condition_poor', 112668],
#   ['tunnel_condition_severe', 15230],
#   ['condition_percentage_good', '95.72%'],
#   ['condition_percentage_fair', '2.74%'],
#   ['condition_percentage_poor', '1.36%'],
#   ['condition_percentage_severe', '0.18%'],
#   ['road_total', 3163.66836],
#   ['not_reported_road', 3.01805],
#   ['road_good', 1383.6976],
#   ['road_fair', 681.6899],
#   ['road_poor', 826.27933],
#   ['not_reported_road_percent', '0.10%'],
#   ['road_good_percent', '43.74%'],
#   ['road_fair_percent', '21.55%'],
#   ['road_poor_percent', '26.12%']],
#  [['bridge_count_all', 4010],
#   ['bridge_count_good', 1519],
#   ['bridge_count_fair', 2259],
#   ['bridge_count_poor', 232],
#   ['bridge_area_all', 2080960],
#   ['bridge_area_good', 750052],
#   ['bridge_area_fair', 1230457],
#   ['bridge_area_poor', 100451],
#   ['bridge_percentage_good', '37.88%'],
#   ['bridge_percentage_fair', '56.33%'],
#   ['bridge_percentage_poor', '5.79%'],
#   ['bridge_area_percent_good', '36.04%'],
#   ['bridge_area_percent_fair', '59.13%'],
#   ['bridge_area_percent_poor', '4.83%'],
#   ['total_tunnel_elements', 65551],
#   ['tunnel_condition_good', 4332],
#   ['tunnel_condition_fair', 50400],
#   ['tunnel_condition_poor', 10819],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '6.61%'],
#   ['condition_percentage_fair', '76.89%'],
#   ['condition_percentage_poor', '16.50%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 5932.72365],
#   ['not_reported_road', 41.05922],
#   ['road_good', 3272.60936],
#   ['road_fair', 1361.96361],
#   ['road_poor', 839.98365],
#   ['not_reported_road_percent', '0.69%'],
#   ['road_good_percent', '55.16%'],
#   ['road_fair_percent', '22.96%'],
#   ['road_poor_percent', '14.16%']],
#  [['bridge_count_all', 17521],
#   ['bridge_count_good', 6400],
#   ['bridge_count_fair', 9364],
#   ['bridge_count_poor', 1757],
#   ['bridge_area_all', 13089606],
#   ['bridge_area_good', 3596940],
#   ['bridge_area_fair', 8164313],
#   ['bridge_area_poor', 1328353],
#   ['bridge_percentage_good', '36.53%'],
#   ['bridge_percentage_fair', '53.44%'],
#   ['bridge_percentage_poor', '10.03%'],
#   ['bridge_area_percent_good', '27.48%'],
#   ['bridge_area_percent_fair', '62.37%'],
#   ['bridge_area_percent_poor', '10.15%'],
#   ['total_tunnel_elements', 12394947],
#   ['tunnel_condition_good', 10606121],
#   ['tunnel_condition_fair', 1424072],
#   ['tunnel_condition_poor', 284410],
#   ['tunnel_condition_severe', 80344],
#   ['condition_percentage_good', '85.57%'],
#   ['condition_percentage_fair', '11.49%'],
#   ['condition_percentage_poor', '2.29%'],
#   ['condition_percentage_severe', '0.65%'],
#   ['road_total', 10837.4077],
#   ['not_reported_road', 272.66056000000003],
#   ['road_good', 5057.83778],
#   ['road_fair', 2938.37955],
#   ['road_poor', 1824.4877],
#   ['not_reported_road_percent', '2.52%'],
#   ['road_good_percent', '46.67%'],
#   ['road_fair_percent', '27.11%'],
#   ['road_poor_percent', '16.84%']],
#  [['bridge_count_all', 18377],
#   ['bridge_count_good', 7186],
#   ['bridge_count_fair', 9313],
#   ['bridge_count_poor', 1871],
#   ['bridge_area_all', 9994006],
#   ['bridge_area_good', 4051533],
#   ['bridge_area_fair', 5028174],
#   ['bridge_area_poor', 910169],
#   ['bridge_percentage_good', '39.10%'],
#   ['bridge_percentage_fair', '50.68%'],
#   ['bridge_percentage_poor', '10.18%'],
#   ['bridge_area_percent_good', '40.54%'],
#   ['bridge_area_percent_fair', '50.31%'],
#   ['bridge_area_percent_poor', '9.11%'],
#   ['total_tunnel_elements', 2690832],
#   ['tunnel_condition_good', 2571323],
#   ['tunnel_condition_fair', 82769],
#   ['tunnel_condition_poor', 36439],
#   ['tunnel_condition_severe', 301],
#   ['condition_percentage_good', '95.56%'],
#   ['condition_percentage_fair', '3.08%'],
#   ['condition_percentage_poor', '1.35%'],
#   ['condition_percentage_severe', '0.01%'],
#   ['road_total', 8418.02759],
#   ['not_reported_road', 86.49091999999999],
#   ['road_good', 5162.87684],
#   ['road_fair', 2118.49599],
#   ['road_poor', 594.4548599999999],
#   ['not_reported_road_percent', '1.03%'],
#   ['road_good_percent', '61.33%'],
#   ['road_fair_percent', '25.17%'],
#   ['road_poor_percent', '7.06%']],
#  [['bridge_count_all', 4355],
#   ['bridge_count_good', 2341],
#   ['bridge_count_fair', 1545],
#   ['bridge_count_poor', 469],
#   ['bridge_area_all', 1320937],
#   ['bridge_area_good', 770811],
#   ['bridge_area_fair', 482267],
#   ['bridge_area_poor', 67859],
#   ['bridge_percentage_good', '53.75%'],
#   ['bridge_percentage_fair', '35.48%'],
#   ['bridge_percentage_poor', '10.77%'],
#   ['bridge_area_percent_good', '58.35%'],
#   ['bridge_area_percent_fair', '36.51%'],
#   ['bridge_area_percent_poor', '5.14%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 6252.4803],
#   ['not_reported_road', 5.8263300000000005],
#   ['road_good', 4875.11712],
#   ['road_fair', 1018.31568],
#   ['road_poor', 208.95725],
#   ['not_reported_road_percent', '0.09%'],
#   ['road_good_percent', '77.97%'],
#   ['road_fair_percent', '16.29%'],
#   ['road_poor_percent', '3.34%']],
#  [['bridge_count_all', 27277],
#   ['bridge_count_good', 15974],
#   ['bridge_count_fair', 9785],
#   ['bridge_count_poor', 1518],
#   ['bridge_area_all', 13956582],
#   ['bridge_area_good', 8043801],
#   ['bridge_area_fair', 5430710],
#   ['bridge_area_poor', 482071],
#   ['bridge_percentage_good', '58.56%'],
#   ['bridge_percentage_fair', '35.87%'],
#   ['bridge_percentage_poor', '5.57%'],
#   ['bridge_area_percent_good', '57.63%'],
#   ['bridge_area_percent_fair', '38.91%'],
#   ['bridge_area_percent_poor', '3.45%'],
#   ['total_tunnel_elements', 360592],
#   ['tunnel_condition_good', 341287],
#   ['tunnel_condition_fair', 13166],
#   ['tunnel_condition_poor', 6011],
#   ['tunnel_condition_severe', 128],
#   ['condition_percentage_good', '94.65%'],
#   ['condition_percentage_fair', '3.65%'],
#   ['condition_percentage_poor', '1.67%'],
#   ['condition_percentage_severe', '0.04%'],
#   ['road_total', 9128.45516],
#   ['not_reported_road', 28.15468],
#   ['road_good', 5837.90755],
#   ['road_fair', 1913.0457199999998],
#   ['road_poor', 899.7866],
#   ['not_reported_road_percent', '0.31%'],
#   ['road_good_percent', '63.95%'],
#   ['road_fair_percent', '20.96%'],
#   ['road_poor_percent', '9.86%']],
#  [['bridge_count_all', 23116],
#   ['bridge_count_good', 10304],
#   ['bridge_count_fair', 10268],
#   ['bridge_count_poor', 2540],
#   ['bridge_area_all', 8738610],
#   ['bridge_area_good', 4203648],
#   ['bridge_area_fair', 3991370],
#   ['bridge_area_poor', 542486],
#   ['bridge_percentage_good', '44.58%'],
#   ['bridge_percentage_fair', '44.42%'],
#   ['bridge_percentage_poor', '10.99%'],
#   ['bridge_area_percent_good', '48.10%'],
#   ['bridge_area_percent_fair', '45.68%'],
#   ['bridge_area_percent_poor', '6.21%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 4631.04522],
#   ['not_reported_road', 747.98768],
#   ['road_good', 2415.25831],
#   ['road_fair', 947.77701],
#   ['road_poor', 305.59984],
#   ['not_reported_road_percent', '16.15%'],
#   ['road_good_percent', '52.15%'],
#   ['road_fair_percent', '20.47%'],
#   ['road_poor_percent', '6.60%']],
#  [['bridge_count_all', 8161],
#   ['bridge_count_good', 2881],
#   ['bridge_count_fair', 4858],
#   ['bridge_count_poor', 422],
#   ['bridge_area_all', 5060329],
#   ['bridge_area_good', 1043269],
#   ['bridge_area_fair', 3829407],
#   ['bridge_area_poor', 187653],
#   ['bridge_percentage_good', '35.30%'],
#   ['bridge_percentage_fair', '59.53%'],
#   ['bridge_percentage_poor', '5.17%'],
#   ['bridge_area_percent_good', '20.62%'],
#   ['bridge_area_percent_fair', '75.68%'],
#   ['bridge_area_percent_poor', '3.71%'],
#   ['total_tunnel_elements', 1271341],
#   ['tunnel_condition_good', 994713],
#   ['tunnel_condition_fair', 242564],
#   ['tunnel_condition_poor', 34028],
#   ['tunnel_condition_severe', 36],
#   ['condition_percentage_good', '78.24%'],
#   ['condition_percentage_fair', '19.08%'],
#   ['condition_percentage_poor', '2.68%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 6506.1492100000005],
#   ['not_reported_road', 12.81655],
#   ['road_good', 4116.36635],
#   ['road_fair', 1883.5557],
#   ['road_poor', 282.76816],
#   ['not_reported_road_percent', '0.20%'],
#   ['road_good_percent', '63.27%'],
#   ['road_fair_percent', '28.95%'],
#   ['road_poor_percent', '4.35%']],
#  [['bridge_count_all', 22737],
#   ['bridge_count_good', 6985],
#   ['bridge_count_fair', 11979],
#   ['bridge_count_poor', 3770],
#   ['bridge_area_all', 13945241],
#   ['bridge_area_good', 3817119],
#   ['bridge_area_fair', 8956109],
#   ['bridge_area_poor', 1170852],
#   ['bridge_percentage_good', '30.72%'],
#   ['bridge_percentage_fair', '52.69%'],
#   ['bridge_percentage_poor', '16.58%'],
#   ['bridge_area_percent_good', '27.37%'],
#   ['bridge_area_percent_fair', '64.22%'],
#   ['bridge_area_percent_poor', '8.40%'],
#   ['total_tunnel_elements', 10964400],
#   ['tunnel_condition_good', 10370833],
#   ['tunnel_condition_fair', 441233],
#   ['tunnel_condition_poor', 150052],
#   ['tunnel_condition_severe', 2282],
#   ['condition_percentage_good', '94.59%'],
#   ['condition_percentage_fair', '4.02%'],
#   ['condition_percentage_poor', '1.37%'],
#   ['condition_percentage_severe', '0.02%'],
#   ['road_total', 11623.71675],
#   ['not_reported_road', 18.5577],
#   ['road_good', 5613.46752],
#   ['road_fair', 3688.69516],
#   ['road_poor', 1446.4495],
#   ['not_reported_road_percent', '0.16%'],
#   ['road_good_percent', '48.29%'],
#   ['road_fair_percent', '31.73%'],
#   ['road_poor_percent', '12.44%']],
#  [['bridge_count_all', 780],
#   ['bridge_count_good', 134],
#   ['bridge_count_fair', 466],
#   ['bridge_count_poor', 180],
#   ['bridge_area_all', 793527],
#   ['bridge_area_good', 109894],
#   ['bridge_area_fair', 493870],
#   ['bridge_area_poor', 189763],
#   ['bridge_percentage_good', '17.18%'],
#   ['bridge_percentage_fair', '59.74%'],
#   ['bridge_percentage_poor', '23.08%'],
#   ['bridge_area_percent_good', '13.85%'],
#   ['bridge_area_percent_fair', '62.24%'],
#   ['bridge_area_percent_poor', '23.91%'],
#   ['total_tunnel_elements', 243146],
#   ['tunnel_condition_good', 162272],
#   ['tunnel_condition_fair', 1572],
#   ['tunnel_condition_poor', 1608],
#   ['tunnel_condition_severe', 77694],
#   ['condition_percentage_good', '66.74%'],
#   ['condition_percentage_fair', '0.65%'],
#   ['condition_percentage_poor', '0.66%'],
#   ['condition_percentage_severe', '31.95%'],
#   ['road_total', 624.53844],
#   ['not_reported_road', 20.75057],
#   ['road_good', 149.66],
#   ['road_fair', 139.76221999999999],
#   ['road_poor', 237.70636000000002],
#   ['not_reported_road_percent', '3.32%'],
#   ['road_good_percent', '23.96%'],
#   ['road_fair_percent', '22.38%'],
#   ['road_poor_percent', '38.06%']],
#  [['bridge_count_all', 9401],
#   ['bridge_count_good', 4225],
#   ['bridge_count_fair', 4381],
#   ['bridge_count_poor', 795],
#   ['bridge_area_all', 6985851],
#   ['bridge_area_good', 3191638],
#   ['bridge_area_fair', 3339881],
#   ['bridge_area_poor', 454332],
#   ['bridge_percentage_good', '44.94%'],
#   ['bridge_percentage_fair', '46.60%'],
#   ['bridge_percentage_poor', '8.46%'],
#   ['bridge_area_percent_good', '45.69%'],
#   ['bridge_area_percent_fair', '47.81%'],
#   ['bridge_area_percent_poor', '6.50%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 6591.5068],
#   ['not_reported_road', 17.880489999999998],
#   ['road_good', 3704.17785],
#   ['road_fair', 2098.31313],
#   ['road_poor', 362.066],
#   ['not_reported_road_percent', '0.27%'],
#   ['road_good_percent', '56.20%'],
#   ['road_fair_percent', '31.83%'],
#   ['road_poor_percent', '5.49%']],
#  [['bridge_count_all', 5824],
#   ['bridge_count_good', 1906],
#   ['bridge_count_fair', 2945],
#   ['bridge_count_poor', 973],
#   ['bridge_area_all', 1803770],
#   ['bridge_area_good', 517279],
#   ['bridge_area_fair', 1142586],
#   ['bridge_area_poor', 143905],
#   ['bridge_percentage_good', '32.73%'],
#   ['bridge_percentage_fair', '50.57%'],
#   ['bridge_percentage_poor', '16.71%'],
#   ['bridge_area_percent_good', '28.68%'],
#   ['bridge_area_percent_fair', '63.34%'],
#   ['bridge_area_percent_poor', '7.98%'],
#   ['total_tunnel_elements', 28054],
#   ['tunnel_condition_good', 24830],
#   ['tunnel_condition_fair', 881],
#   ['tunnel_condition_poor', 14],
#   ['tunnel_condition_severe', 2329],
#   ['condition_percentage_good', '88.51%'],
#   ['condition_percentage_fair', '3.14%'],
#   ['condition_percentage_poor', '0.05%'],
#   ['condition_percentage_severe', '8.30%'],
#   ['road_total', 6626.033579999999],
#   ['not_reported_road', 50.11042],
#   ['road_good', 4001.5195700000004],
#   ['road_fair', 1844.2499899999998],
#   ['road_poor', 369.17445],
#   ['not_reported_road_percent', '0.76%'],
#   ['road_good_percent', '60.39%'],
#   ['road_fair_percent', '27.83%'],
#   ['road_poor_percent', '5.57%']],
#  [['bridge_count_all', 20177],
#   ['bridge_count_good', 9221],
#   ['bridge_count_fair', 10084],
#   ['bridge_count_poor', 871],
#   ['bridge_area_all', 10275911],
#   ['bridge_area_good', 4306805],
#   ['bridge_area_fair', 5561752],
#   ['bridge_area_poor', 407294],
#   ['bridge_percentage_good', '45.70%'],
#   ['bridge_percentage_fair', '49.98%'],
#   ['bridge_percentage_poor', '4.32%'],
#   ['bridge_area_percent_good', '41.91%'],
#   ['bridge_area_percent_fair', '54.12%'],
#   ['bridge_area_percent_poor', '3.96%'],
#   ['total_tunnel_elements', 1545660],
#   ['tunnel_condition_good', 1418081],
#   ['tunnel_condition_fair', 46920],
#   ['tunnel_condition_poor', 73286],
#   ['tunnel_condition_severe', 7373],
#   ['condition_percentage_good', '91.75%'],
#   ['condition_percentage_fair', '3.04%'],
#   ['condition_percentage_poor', '4.74%'],
#   ['condition_percentage_severe', '0.48%'],
#   ['road_total', 5146.652929999999],
#   ['not_reported_road', 203.50228],
#   ['road_good', 3736.2294100000004],
#   ['road_fair', 786.09464],
#   ['road_poor', 256.1366],
#   ['not_reported_road_percent', '3.95%'],
#   ['road_good_percent', '72.60%'],
#   ['road_fair_percent', '15.27%'],
#   ['road_poor_percent', '4.98%']],
#  [['bridge_count_all', 54131],
#   ['bridge_count_good', 28020],
#   ['bridge_count_fair', 25411],
#   ['bridge_count_poor', 695],
#   ['bridge_area_all', 50368715],
#   ['bridge_area_good', 26200337],
#   ['bridge_area_fair', 23665660],
#   ['bridge_area_poor', 502093],
#   ['bridge_percentage_good', '51.76%'],
#   ['bridge_percentage_fair', '46.94%'],
#   ['bridge_percentage_poor', '1.28%'],
#   ['bridge_area_percent_good', '52.02%'],
#   ['bridge_area_percent_fair', '46.98%'],
#   ['bridge_area_percent_poor', '1.00%'],
#   ['total_tunnel_elements', 704271],
#   ['tunnel_condition_good', 677869],
#   ['tunnel_condition_fair', 19936],
#   ['tunnel_condition_poor', 6459],
#   ['tunnel_condition_severe', 7],
#   ['condition_percentage_good', '96.25%'],
#   ['condition_percentage_fair', '2.83%'],
#   ['condition_percentage_poor', '0.92%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 20235.09604],
#   ['not_reported_road', 261.93392],
#   ['road_good', 11651.48818],
#   ['road_fair', 5069.13916],
#   ['road_poor', 2123.2226],
#   ['not_reported_road_percent', '1.29%'],
#   ['road_good_percent', '57.58%'],
#   ['road_fair_percent', '25.05%'],
#   ['road_poor_percent', '10.49%']],
#  [['bridge_count_all', 3061],
#   ['bridge_count_good', 1659],
#   ['bridge_count_fair', 1336],
#   ['bridge_count_poor', 66],
#   ['bridge_area_all', 1948005],
#   ['bridge_area_good', 1013841],
#   ['bridge_area_fair', 919942],
#   ['bridge_area_poor', 14222],
#   ['bridge_percentage_good', '54.20%'],
#   ['bridge_percentage_fair', '43.65%'],
#   ['bridge_percentage_poor', '2.16%'],
#   ['bridge_area_percent_good', '52.05%'],
#   ['bridge_area_percent_fair', '47.22%'],
#   ['bridge_area_percent_poor', '0.73%'],
#   ['total_tunnel_elements', 546422],
#   ['tunnel_condition_good', 295458],
#   ['tunnel_condition_fair', 190848],
#   ['tunnel_condition_poor', 60107],
#   ['tunnel_condition_severe', 9],
#   ['condition_percentage_good', '54.07%'],
#   ['condition_percentage_fair', '34.93%'],
#   ['condition_percentage_poor', '11.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 4128.19285],
#   ['not_reported_road', 12.70427],
#   ['road_good', 2542.94788],
#   ['road_fair', 1150.0062],
#   ['road_poor', 204.26975],
#   ['not_reported_road_percent', '0.31%'],
#   ['road_good_percent', '61.60%'],
#   ['road_fair_percent', '27.86%'],
#   ['road_poor_percent', '4.95%']],
#  [['bridge_count_all', 2778],
#   ['bridge_count_good', 1473],
#   ['bridge_count_fair', 1239],
#   ['bridge_count_poor', 66],
#   ['bridge_area_all', 884043],
#   ['bridge_area_good', 451405],
#   ['bridge_area_fair', 404534],
#   ['bridge_area_poor', 28104],
#   ['bridge_percentage_good', '53.02%'],
#   ['bridge_percentage_fair', '44.60%'],
#   ['bridge_percentage_poor', '2.38%'],
#   ['bridge_area_percent_good', '51.06%'],
#   ['bridge_area_percent_fair', '45.76%'],
#   ['bridge_area_percent_poor', '3.18%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 1530.25338],
#   ['not_reported_road', 9.03369],
#   ['road_good', 1023.1047800000001],
#   ['road_fair', 327.87622000000005],
#   ['road_poor', 97.33748],
#   ['not_reported_road_percent', '0.59%'],
#   ['road_good_percent', '66.86%'],
#   ['road_fair_percent', '21.43%'],
#   ['road_poor_percent', '6.36%']],
#  [['bridge_count_all', 13931],
#   ['bridge_count_good', 4786],
#   ['bridge_count_fair', 8499],
#   ['bridge_count_poor', 646],
#   ['bridge_area_all', 10125635],
#   ['bridge_area_good', 3560099],
#   ['bridge_area_fair', 6146720],
#   ['bridge_area_poor', 418815],
#   ['bridge_percentage_good', '34.36%'],
#   ['bridge_percentage_fair', '61.01%'],
#   ['bridge_percentage_poor', '4.64%'],
#   ['bridge_area_percent_good', '35.16%'],
#   ['bridge_area_percent_fair', '60.70%'],
#   ['bridge_area_percent_poor', '4.14%'],
#   ['total_tunnel_elements', 15650338],
#   ['tunnel_condition_good', 15011859],
#   ['tunnel_condition_fair', 457348],
#   ['tunnel_condition_poor', 169969],
#   ['tunnel_condition_severe', 11162],
#   ['condition_percentage_good', '95.92%'],
#   ['condition_percentage_fair', '2.92%'],
#   ['condition_percentage_poor', '1.09%'],
#   ['condition_percentage_severe', '0.07%'],
#   ['road_total', 8126.95012],
#   ['not_reported_road', 38.556020000000004],
#   ['road_good', 4610.93642],
#   ['road_fair', 2675.5992899999997],
#   ['road_poor', 380.92071],
#   ['not_reported_road_percent', '0.47%'],
#   ['road_good_percent', '56.74%'],
#   ['road_fair_percent', '32.92%'],
#   ['road_poor_percent', '4.69%']],
#  [['bridge_count_all', 8278],
#   ['bridge_count_good', 4317],
#   ['bridge_count_fair', 3579],
#   ['bridge_count_poor', 382],
#   ['bridge_area_all', 7224042],
#   ['bridge_area_good', 2790592],
#   ['bridge_area_fair', 3893877],
#   ['bridge_area_poor', 539572],
#   ['bridge_percentage_good', '52.15%'],
#   ['bridge_percentage_fair', '43.24%'],
#   ['bridge_percentage_poor', '4.61%'],
#   ['bridge_area_percent_good', '38.63%'],
#   ['bridge_area_percent_fair', '53.90%'],
#   ['bridge_area_percent_poor', '7.47%'],
#   ['total_tunnel_elements', 9133405],
#   ['tunnel_condition_good', 9045155],
#   ['tunnel_condition_fair', 54566],
#   ['tunnel_condition_poor', 30920],
#   ['tunnel_condition_severe', 2764],
#   ['condition_percentage_good', '99.03%'],
#   ['condition_percentage_fair', '0.60%'],
#   ['condition_percentage_poor', '0.34%'],
#   ['condition_percentage_severe', '0.03%'],
#   ['road_total', 6588.83109],
#   ['not_reported_road', 32.62911],
#   ['road_good', 3219.97277],
#   ['road_fair', 1842.4835899999998],
#   ['road_poor', 1006.8738199999999],
#   ['not_reported_road_percent', '0.50%'],
#   ['road_good_percent', '48.87%'],
#   ['road_fair_percent', '27.96%'],
#   ['road_poor_percent', '15.28%']],
#  [['bridge_count_all', 7269],
#   ['bridge_count_good', 1978],
#   ['bridge_count_fair', 3844],
#   ['bridge_count_poor', 1444],
#   ['bridge_area_all', 3811742],
#   ['bridge_area_good', 743138],
#   ['bridge_area_fair', 2535381],
#   ['bridge_area_poor', 532829],
#   ['bridge_percentage_good', '27.21%'],
#   ['bridge_percentage_fair', '52.88%'],
#   ['bridge_percentage_poor', '19.87%'],
#   ['bridge_area_percent_good', '19.50%'],
#   ['bridge_area_percent_fair', '66.52%'],
#   ['bridge_area_percent_poor', '13.98%'],
#   ['total_tunnel_elements', 2874651],
#   ['tunnel_condition_good', 2707789],
#   ['tunnel_condition_fair', 116889],
#   ['tunnel_condition_poor', 14347],
#   ['tunnel_condition_severe', 35626],
#   ['condition_percentage_good', '94.20%'],
#   ['condition_percentage_fair', '4.07%'],
#   ['condition_percentage_poor', '0.50%'],
#   ['condition_percentage_severe', '1.24%'],
#   ['road_total', 3335.09961],
#   ['not_reported_road', 30.40148],
#   ['road_good', 1700.45427],
#   ['road_fair', 1105.5744300000001],
#   ['road_poor', 275.97335],
#   ['not_reported_road_percent', '0.91%'],
#   ['road_good_percent', '50.99%'],
#   ['road_fair_percent', '33.15%'],
#   ['road_poor_percent', '8.27%']],
#  [['bridge_count_all', 14275],
#   ['bridge_count_good', 7383],
#   ['bridge_count_fair', 5838],
#   ['bridge_count_poor', 1054],
#   ['bridge_area_all', 7006791],
#   ['bridge_area_good', 3677689],
#   ['bridge_area_fair', 3034479],
#   ['bridge_area_poor', 294623],
#   ['bridge_percentage_good', '51.72%'],
#   ['bridge_percentage_fair', '40.90%'],
#   ['bridge_percentage_poor', '7.38%'],
#   ['bridge_area_percent_good', '52.49%'],
#   ['bridge_area_percent_fair', '43.31%'],
#   ['bridge_area_percent_poor', '4.20%'],
#   ['total_tunnel_elements', 0],
#   ['tunnel_condition_good', 0],
#   ['tunnel_condition_fair', 0],
#   ['tunnel_condition_poor', 0],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '0.00%'],
#   ['condition_percentage_fair', '0.00%'],
#   ['condition_percentage_poor', '0.00%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 10873.22564],
#   ['not_reported_road', 25.822],
#   ['road_good', 5493.0889],
#   ['road_fair', 2812.223],
#   ['road_poor', 1638.9912800000002],
#   ['not_reported_road_percent', '0.24%'],
#   ['road_good_percent', '50.52%'],
#   ['road_fair_percent', '25.86%'],
#   ['road_poor_percent', '15.07%']],
#  [['bridge_count_all', 3129],
#   ['bridge_count_good', 926],
#   ['bridge_count_fair', 1946],
#   ['bridge_count_poor', 257],
#   ['bridge_area_all', 1339545],
#   ['bridge_area_good', 317802],
#   ['bridge_area_fair', 900448],
#   ['bridge_area_poor', 121296],
#   ['bridge_percentage_good', '29.59%'],
#   ['bridge_percentage_fair', '62.19%'],
#   ['bridge_percentage_poor', '8.21%'],
#   ['bridge_area_percent_good', '23.72%'],
#   ['bridge_area_percent_fair', '67.22%'],
#   ['bridge_area_percent_poor', '9.06%'],
#   ['total_tunnel_elements', 721597],
#   ['tunnel_condition_good', 670708],
#   ['tunnel_condition_fair', 37035],
#   ['tunnel_condition_poor', 12393],
#   ['tunnel_condition_severe', 1461],
#   ['condition_percentage_good', '92.95%'],
#   ['condition_percentage_fair', '5.13%'],
#   ['condition_percentage_poor', '1.72%'],
#   ['condition_percentage_severe', '0.20%'],
#   ['road_total', 1696.0297899999998],
#   ['not_reported_road', 33.122],
#   ['road_good', 763.1669999999999],
#   ['road_fair', 251.19324],
#   ['road_poor', 536.95315],
#   ['not_reported_road_percent', '1.95%'],
#   ['road_good_percent', '45.00%'],
#   ['road_fair_percent', '14.81%'],
#   ['road_poor_percent', '31.66%']],
#  [['bridge_count_all', 2325],
#   ['bridge_count_good', 444],
#   ['bridge_count_fair', 1608],
#   ['bridge_count_poor', 273],
#   ['bridge_area_all', 2180690],
#   ['bridge_area_good', 459866],
#   ['bridge_area_fair', 1525035],
#   ['bridge_area_poor', 195789],
#   ['bridge_percentage_good', '19.10%'],
#   ['bridge_percentage_fair', '69.16%'],
#   ['bridge_percentage_poor', '11.74%'],
#   ['bridge_area_percent_good', '21.09%'],
#   ['bridge_area_percent_fair', '69.93%'],
#   ['bridge_area_percent_poor', '8.98%'],
#   ['total_tunnel_elements', 1210235],
#   ['tunnel_condition_good', 1197586],
#   ['tunnel_condition_fair', 8698],
#   ['tunnel_condition_poor', 3951],
#   ['tunnel_condition_severe', 0],
#   ['condition_percentage_good', '98.95%'],
#   ['condition_percentage_fair', '0.72%'],
#   ['condition_percentage_poor', '0.33%'],
#   ['condition_percentage_severe', '0.00%'],
#   ['road_total', 0.0],
#   ['not_reported_road', 0.0],
#   ['road_good', 0.0],
#   ['road_fair', 0.0],
#   ['road_poor', 0.0],
#   ['not_reported_road_percent', '0.00%'],
#   ['road_good_percent', '0.00%'],
#   ['road_fair_percent', '0.00%'],
#   ['road_poor_percent', '0.00%']]]

# %%
for i in range(0,len(bridge_state)):
    
    feature = features[i]
    properties = bridge_state[i]
    json_normalize(feature)
    
    for property in properties:
        feature["properties"][property[0]]=property[1]
        
json_normalize(features)
# Out:
#                                  geometry.coordinates geometry.type  \
# 0   [[[[-88.124658, 30.28364], [-88.086812, 30.259...  MultiPolygon
# 1   [[[[-166.10574, 53.988606], [-166.075283, 53.9...  MultiPolygon
# 2   [[[-112.538593, 37.000674], [-112.534545, 37.0...       Polygon
# 3   [[[-94.042964, 33.019219], [-94.043036, 33.079...       Polygon
# 4   [[[[-122.421439, 37.869969], [-122.421341, 37....  MultiPolygon
# 5   [[[-106.190554, 40.997607], [-106.061181, 40.9...       Polygon
# 6   [[[-71.799242, 42.008065], [-71.797922, 41.935...       Polygon
# 7   [[[[-75.564927, 39.583248], [-75.576271, 39.58...  MultiPolygon
# 8   [[[-77.038598, 38.791513], [-77.038898, 38.800...       Polygon
# 9   [[[[-82.821585, 27.964443], [-82.829801, 27.96...  MultiPolygon
# 10  [[[-84.810477, 34.987607], [-84.809184, 34.987...       Polygon
# 11  [[[[-155.778234, 20.245743], [-155.772734, 20....  MultiPolygon
# 12  [[[-111.044156, 43.020052], [-111.044129, 43.0...       Polygon
# 13  [[[-89.366031, 42.500274], [-89.361561, 42.500...       Polygon
# 14  [[[-84.802483, 40.528046], [-84.802547, 40.501...       Polygon
# 15  [[[-91.217706, 43.50055], [-91.21827, 43.49722...       Polygon
# 16  [[[-99.541116, 36.999573], [-99.558068, 36.999...       Polygon
# 17  [[[[-89.485106, 36.497692], [-89.492537, 36.49...  MultiPolygon
# 18  [[[[-88.865067, 29.752714], [-88.889755, 29.71...  MultiPolygon
# 19  [[[[-70.152589, 43.746794], [-70.151959, 43.74...  MultiPolygon
# 20  [[[[-76.048373, 38.12055], [-76.056811, 38.125...  MultiPolygon
# 21  [[[[-70.827398, 41.602067], [-70.823735, 41.59...  MultiPolygon
# 22  [[[[-85.825955, 45.404296], [-85.833516, 45.37...  MultiPolygon
# 23  [[[-92.204691, 46.704041], [-92.205692, 46.702...       Polygon
# 24  [[[[-89.095623, 30.231767], [-89.077259, 30.23...  MultiPolygon
# 25  [[[-89.545006, 36.336809], [-89.560439, 36.337...       Polygon
# 26  [[[-105.038405, 45.000345], [-105.076607, 45.0...       Polygon
# 27  [[[-104.053249, 41.001406], [-104.053158, 41.0...       Polygon
# 28  [[[-114.042145, 40.999926], [-114.043176, 40.7...       Polygon
# 29  [[[-72.4521, 43.161414], [-72.451868, 43.17017...       Polygon
# 30  [[[-75.210876, 39.865709], [-75.210425, 39.865...       Polygon
# 31  [[[-105.998003, 32.002328], [-106.099756, 32.0...       Polygon
# 32  [[[[-74.04086, 40.700117], [-74.040018, 40.700...  MultiPolygon
# 33  [[[[-75.753765, 35.199612], [-75.74522, 35.203...  MultiPolygon
# 34  [[[-98.724375, 45.938686], [-98.904429, 45.939...       Polygon
# 35  [[[[-82.835118, 41.708971], [-82.82572, 41.722...  MultiPolygon
# 36  [[[-96.944611, 33.949217], [-96.952313, 33.944...       Polygon
# 37  [[[-121.922236, 45.649083], [-121.908267, 45.6...       Polygon
# 38  [[[-79.916171, 39.720893], [-80.075947, 39.721...       Polygon
# 39  [[[[-71.383586, 41.464782], [-71.389284, 41.46...  MultiPolygon
# 40  [[[-79.290754, 33.110051], [-79.291591, 33.109...       Polygon
# 41  [[[-104.054487, 44.180381], [-104.055389, 44.2...       Polygon
# 42  [[[-83.472108, 36.597284], [-83.374904, 36.597...       Polygon
# 43  [[[[-97.134356, 27.896329], [-97.1336, 27.8974...  MultiPolygon
# 44  [[[-111.046551, 41.251716], [-111.046723, 40.9...       Polygon
# 45  [[[-72.433796, 43.232999], [-72.434466, 43.230...       Polygon
# 46  [[[[-75.973607, 37.835817], [-75.971705, 37.83...  MultiPolygon
# 47  [[[[-122.519535, 48.288314], [-122.522756, 48....  MultiPolygon
# 48  [[[-80.075947, 39.72135], [-79.916171, 39.7208...       Polygon
# 49  [[[[-90.403306, 47.026693], [-90.403321, 47.02...  MultiPolygon
# 50  [[[-110.048476, 40.997555], [-110.121639, 40.9...       Polygon
# 51  [[[[-65.3277, 18.295843], [-65.337451, 18.3083...  MultiPolygon
#
#     properties.CENSUSAREA properties.GEO_ID properties.LSAD  \
# 0               50645.326       0400000US01
# 1              570640.950       0400000US02
# 2              113594.084       0400000US04
# 3               52035.477       0400000US05
# 4              155779.220       0400000US06
# 5              103641.888       0400000US08
# 6                4842.355       0400000US09
# 7                1948.543       0400000US10
# 8                  61.048       0400000US11
# 9               53624.759       0400000US12
# 10              57513.485       0400000US13
# 11               6422.628       0400000US15
# 12              82643.117       0400000US16
# 13              55518.930       0400000US17
# 14              35826.109       0400000US18
# 15              55857.130       0400000US19
# 16              81758.717       0400000US20
# 17              39486.338       0400000US21
# 18              43203.905       0400000US22
# 19              30842.923       0400000US23
# 20               9707.241       0400000US24
# 21               7800.058       0400000US25
# 22              56538.901       0400000US26
# 23              79626.743       0400000US27
# 24              46923.274       0400000US28
# 25              68741.522       0400000US29
# 26             145545.801       0400000US30
# 27              76824.171       0400000US31
# 28             109781.180       0400000US32
# 29               8952.651       0400000US33
# 30               7354.220       0400000US34
# 31             121298.148       0400000US35
# 32              47126.399       0400000US36
# 33              48617.905       0400000US37
# 34              69000.798       0400000US38
# 35              40860.694       0400000US39
# 36              68594.921       0400000US40
# 37              95988.013       0400000US41
# 38              44742.703       0400000US42
# 39               1033.814       0400000US44
# 40              30060.696       0400000US45
# 41              75811.000       0400000US46
# 42              41234.896       0400000US47
# 43             261231.711       0400000US48
# 44              82169.620       0400000US49
# 45               9216.657       0400000US50
# 46              39490.086       0400000US51
# 47              66455.521       0400000US53
# 48              24038.210       0400000US54
# 49              54157.805       0400000US55
# 50              97093.141       0400000US56
# 51               3423.775       0400000US72
#
#          properties.NAME properties.STATE  properties.bridge_area_all  \
# 0                Alabama               01                     9760735
# 1                 Alaska               02                      743788
# 2                Arizona               04                     5846176
# 3               Arkansas               05                     6708589
# 4             California               06                    30067631
# 5               Colorado               08                     5024622
# 6            Connecticut               09                     3414833
# 7               Delaware               10                     1000357
# 8   District of Columbia               11                      569296
# 9                Florida               12                    17516213
# 10               Georgia               13                    10082064
# 11                Hawaii               15                     1324180
# 12                 Idaho               16                     1756871
# 13              Illinois               17                    13524885
# 14               Indiana               18                     8197646
# 15                  Iowa               19                     8806907
# 16                Kansas               20                     8680998
# 17              Kentucky               21                     6509802
# 18             Louisiana               22                    16587147
# 19                 Maine               23                     1264519
# 20              Maryland               24                     5426511
# 21         Massachusetts               25                     4119863
# 22              Michigan               26                     6445678
# 23             Minnesota               27                     7132639
# 24           Mississippi               28                     9940070
# 25              Missouri               29                    10701764
# 26               Montana               30                     2084807
# 27              Nebraska               31                     4340537
# 28                Nevada               32                     1791492
# 29         New Hampshire               33                     1130225
# 30            New Jersey               34                     7002430
# 31            New Mexico               35                     2080960
# 32              New York               36                    13089606
# 33        North Carolina               37                     9994006
# 34          North Dakota               38                     1320937
# 35                  Ohio               39                    13956582
# 36              Oklahoma               40                     8738610
# 37                Oregon               41                     5060329
# 38          Pennsylvania               42                    13945241
# 39          Rhode Island               44                      793527
# 40        South Carolina               45                     6985851
# 41          South Dakota               46                     1803770
# 42             Tennessee               47                    10275911
# 43                 Texas               48                    50368715
# 44                  Utah               49                     1948005
# 45               Vermont               50                      884043
# 46              Virginia               51                    10125635
# 47            Washington               53                     7224042
# 48         West Virginia               54                     3811742
# 49             Wisconsin               55                     7006791
# 50               Wyoming               56                     1339545
# 51           Puerto Rico               72                     2180690
#
#     properties.bridge_area_fair  properties.bridge_area_good  ...  \
# 0                       5851785                      3661978  ...
# 1                        385915                       298515  ...
# 2                       2581507                      3169212  ...
# 3                       2919170                      3475609  ...
# 4                      10442456                     17623112  ...
# 5                       2457413                      2359789  ...
# 6                       2406635                       600502  ...
# 7                        800016                       141858  ...
# 8                        470820                        75891  ...
# 9                       5575956                     11658699  ...
# 10                      5205927                      4640184  ...
# 11                       968926                       326663  ...
# 12                      1229647                       442282  ...
# 13                      6999849                      5027056  ...
# 14                      4134643                      3735606  ...
# 15                      3872593                      4044915  ...
# 16                      2743165                      5693563  ...
# 17                      3717280                      2480985  ...
# 18                      7449875                      7752468  ...
# 19                       708474                       451266  ...
# 20                      3648777                      1602956  ...
# 21                      2766279                       869419  ...
# 22                      3564054                      2281475  ...
# 23                      3022860                      3859452  ...
# 24                      3019248                      6504401  ...
# 25                      5466291                      4325670  ...
# 26                      1463582                       459891  ...
# 27                      1528921                      2586969  ...
# 28                       939426                       838231  ...
# 29                       404980                       631927  ...
# 30                      4852975                      1654510  ...
# 31                      1230457                       750052  ...
# 32                      8164313                      3596940  ...
# 33                      5028174                      4051533  ...
# 34                       482267                       770811  ...
# 35                      5430710                      8043801  ...
# 36                      3991370                      4203648  ...
# 37                      3829407                      1043269  ...
# 38                      8956109                      3817119  ...
# 39                       493870                       109894  ...
# 40                      3339881                      3191638  ...
# 41                      1142586                       517279  ...
# 42                      5561752                      4306805  ...
# 43                     23665660                     26200337  ...
# 44                       919942                      1013841  ...
# 45                       404534                       451405  ...
# 46                      6146720                      3560099  ...
# 47                      3893877                      2790592  ...
# 48                      2535381                       743138  ...
# 49                      3034479                      3677689  ...
# 50                       900448                       317802  ...
# 51                      1525035                       459866  ...
#
#    properties.road_good_percent properties.road_poor  \
# 0                        80.18%            220.39271
# 1                        36.94%            436.10563
# 2                        59.54%            289.53975
# 3                        56.71%            502.15671
# 4                        38.06%           5005.21738
# 5                        47.12%            937.00781
# 6                        46.27%            234.82630
# 7                        62.78%             39.56467
# 8                         2.54%            111.36500
# 9                        77.40%            320.18109
# 10                       66.81%            284.34236
# 11                       28.22%            167.59800
# 12                       66.90%            111.87102
# 13                       54.74%           1130.71753
# 14                       60.37%            397.29234
# 15                       57.61%            470.99500
# 16                       80.84%            177.65511
# 17                       68.63%            207.06101
# 18                       45.09%            692.43044
# 19                       60.57%            254.67000
# 20                       64.10%            345.37242
# 21                       39.00%            899.95182
# 22                       63.42%           1104.13088
# 23                       61.67%            894.65814
# 24                       57.56%            711.67987
# 25                       61.16%            550.97050
# 26                       68.50%            345.73368
# 27                       72.58%            438.94634
# 28                       82.27%             63.94607
# 29                       70.39%            183.21678
# 30                       43.74%            826.27933
# 31                       55.16%            839.98365
# 32                       46.67%           1824.48770
# 33                       61.33%            594.45486
# 34                       77.97%            208.95725
# 35                       63.95%            899.78660
# 36                       52.15%            305.59984
# 37                       63.27%            282.76816
# 38                       48.29%           1446.44950
# 39                       23.96%            237.70636
# 40                       56.20%            362.06600
# 41                       60.39%            369.17445
# 42                       72.60%            256.13660
# 43                       57.58%           2123.22260
# 44                       61.60%            204.26975
# 45                       66.86%             97.33748
# 46                       56.74%            380.92071
# 47                       48.87%           1006.87382
# 48                       50.99%            275.97335
# 49                       50.52%           1638.99128
# 50                       45.00%            536.95315
# 51                        0.00%              0.00000
#
#    properties.road_poor_percent  properties.road_total  \
# 0                         2.64%             8345.55725
# 1                        17.90%             2436.94823
# 2                         6.20%             4668.39580
# 3                         7.76%             6472.53981
# 4                        24.65%            20302.04369
# 5                        11.13%             8416.97253
# 6                        14.00%             1677.32807
# 7                         7.90%              500.87859
# 8                        83.19%              133.86100
# 9                         2.90%            11021.73667
# 10                        2.33%            12190.23568
# 11                       24.23%              691.67000
# 12                        2.82%             3967.99987
# 13                        9.18%            12318.03017
# 14                        5.35%             7427.28897
# 15                        9.19%             5125.28376
# 16                        2.05%             8673.25457
# 17                        3.69%             5605.21103
# 18                       13.75%             5037.27786
# 19                       11.30%             2253.80800
# 20                       11.83%             2920.05176
# 21                       27.33%             3292.65681
# 22                        9.75%            11322.30921
# 23                        7.65%            11692.47107
# 24                        9.60%             7416.30245
# 25                        5.64%             9769.67309
# 26                        4.88%             7081.57227
# 27                        5.81%             7549.25896
# 28                        1.94%             3291.20628
# 29                       12.36%             1482.88402
# 30                       26.12%             3163.66836
# 31                       14.16%             5932.72365
# 32                       16.84%            10837.40770
# 33                        7.06%             8418.02759
# 34                        3.34%             6252.48030
# 35                        9.86%             9128.45516
# 36                        6.60%             4631.04522
# 37                        4.35%             6506.14921
# 38                       12.44%            11623.71675
# 39                       38.06%              624.53844
# 40                        5.49%             6591.50680
# 41                        5.57%             6626.03358
# 42                        4.98%             5146.65293
# 43                       10.49%            20235.09604
# 44                        4.95%             4128.19285
# 45                        6.36%             1530.25338
# 46                        4.69%             8126.95012
# 47                       15.28%             6588.83109
# 48                        8.27%             3335.09961
# 49                       15.07%            10873.22564
# 50                       31.66%             1696.02979
# 51                        0.00%                0.00000
#
#     properties.total_tunnel_elements  properties.tunnel_condition_fair  \
# 0                            1998282                            251583
# 1                            1098774                            511542
# 2                            1750631                            164065
# 3                             376491                              9322
# 4                           16724871                            309136
# 5                            8393243                            513824
# 6                             847174                             26306
# 7                                  0                                 0
# 8                            2080205                            188719
# 9                            2877174                              4442
# 10                            353991                             12364
# 11                           2850196                            144961
# 12                            377722                             50612
# 13                            716184                            135014
# 14                            845234                             56743
# 15                             11754                               535
# 16                                 0                                 0
# 17                           1830111                            172369
# 18                            867135                            154903
# 19                                 0                                 0
# 20                           9210642                            629737
# 21                          21869922                            789875
# 22                           3821360                            303290
# 23                           1618213                             56271
# 24                                 0                                 0
# 25                            487244                              7986
# 26                            122998                             34368
# 27                             48963                              1201
# 28                           1445150                             71870
# 29                                 0                                 0
# 30                           8281076                            226542
# 31                             65551                             50400
# 32                          12394947                           1424072
# 33                           2690832                             82769
# 34                                 0                                 0
# 35                            360592                             13166
# 36                                 0                                 0
# 37                           1271341                            242564
# 38                          10964400                            441233
# 39                            243146                              1572
# 40                                 0                                 0
# 41                             28054                               881
# 42                           1545660                             46920
# 43                            704271                             19936
# 44                            546422                            190848
# 45                                 0                                 0
# 46                          15650338                            457348
# 47                           9133405                             54566
# 48                           2874651                            116889
# 49                                 0                                 0
# 50                            721597                             37035
# 51                           1210235                              8698
#
#     properties.tunnel_condition_good  properties.tunnel_condition_poor  \
# 0                            1725296                             21191
# 1                             353522                            188371
# 2                            1554508                             28904
# 3                             366899                               269
# 4                           15872091                            321655
# 5                            7399138                            463503
# 6                             798660                             21969
# 7                                  0                                 0
# 8                            1881520                              8879
# 9                            2872013                               596
# 10                            338613                              2997
# 11                           2477234                            227997
# 12                            205950                            108733
# 13                            580246                               924
# 14                            756899                             28362
# 15                             10999                               220
# 16                                 0                                 0
# 17                           1632734                             24583
# 18                            695170                             15968
# 19                                 0                                 0
# 20                           8534504                             36737
# 21                          20794668                            250255
# 22                           3351279                             28488
# 23                           1558245                              3552
# 24                                 0                                 0
# 25                            477394                              1860
# 26                             41881                             41177
# 27                             45393                              2369
# 28                           1322764                             50104
# 29                                 0                                 0
# 30                           7926636                            112668
# 31                              4332                             10819
# 32                          10606121                            284410
# 33                           2571323                             36439
# 34                                 0                                 0
# 35                            341287                              6011
# 36                                 0                                 0
# 37                            994713                             34028
# 38                          10370833                            150052
# 39                            162272                              1608
# 40                                 0                                 0
# 41                             24830                                14
# 42                           1418081                             73286
# 43                            677869                              6459
# 44                            295458                             60107
# 45                                 0                                 0
# 46                          15011859                            169969
# 47                           9045155                             30920
# 48                           2707789                             14347
# 49                                 0                                 0
# 50                            670708                             12393
# 51                           1197586                              3951
#
#    properties.tunnel_condition_severe     type
# 0                                 212  Feature
# 1                               45339  Feature
# 2                                3154  Feature
# 3                                   1  Feature
# 4                              221989  Feature
# 5                               16778  Feature
# 6                                 239  Feature
# 7                                   0  Feature
# 8                                1087  Feature
# 9                                 123  Feature
# 10                                 17  Feature
# 11                                  4  Feature
# 12                              12427  Feature
# 13                                  0  Feature
# 14                               3230  Feature
# 15                                  0  Feature
# 16                                  0  Feature
# 17                                425  Feature
# 18                               1094  Feature
# 19                                  0  Feature
# 20                               9664  Feature
# 21                              35124  Feature
# 22                             138303  Feature
# 23                                145  Feature
# 24                                  0  Feature
# 25                                  4  Feature
# 26                               5572  Feature
# 27                                  0  Feature
# 28                                412  Feature
# 29                                  0  Feature
# 30                              15230  Feature
# 31                                  0  Feature
# 32                              80344  Feature
# 33                                301  Feature
# 34                                  0  Feature
# 35                                128  Feature
# 36                                  0  Feature
# 37                                 36  Feature
# 38                               2282  Feature
# 39                              77694  Feature
# 40                                  0  Feature
# 41                               2329  Feature
# 42                               7373  Feature
# 43                                  7  Feature
# 44                                  9  Feature
# 45                                  0  Feature
# 46                              11162  Feature
# 47                               2764  Feature
# 48                              35626  Feature
# 49                                  0  Feature
# 50                               1461  Feature
# 51                                  0  Feature
#
# [52 rows x 40 columns]

# %%
# export modified json file
state_geo.to_json("updated_infrastructure_condition_2018.json")

# %%
state_geo
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 1   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 2   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 3   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 4   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 5   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 6   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 7   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 8   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 9   FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 10  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 11  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 12  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 13  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 14  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 15  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 16  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 17  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 18  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 19  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 20  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 21  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 22  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 23  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 24  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 25  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 26  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 27  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 28  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 29  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 30  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 31  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 32  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 33  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 34  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 35  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 36  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 37  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 38  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 39  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 40  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 41  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 42  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 43  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 44  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 45  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 46  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 47  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 48  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 49  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 50  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
# 51  FeatureCollection  {'type': 'Feature', 'properties': {'GEO_ID': '...
